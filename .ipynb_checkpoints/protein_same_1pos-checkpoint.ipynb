# %%
from random import *
import csv

# %%
DNA_codon_table = [
        ("ATG","M/Start"), ("ATA","I"), ("ATC","I"), ("ATT","I"), ("ACG","T"), ("ACA","T"),
        ("ACC","T"), ("ACT", "T"), ("AAG","K"), ("AAA","K"), ("AAC","N"), ("AAT","N"),
        ("AGG","R"), ("AGA","R"), ("AGC","S"), ("AGT","S"), 
        ("GTG","V"), ("GTA","V"), ("GTC","V"), ("GTT","V"), ("GCG","A"), ("GCA","A"), ("GCC","A"), ("GCT","A"), 
        ("GAG","E"), ("GAA","E"), ("GAC","D"), ("GAT","D"), ("GGG","G"), ("GGA","G"), ("GGC","G"), ("GGT","G"), 
        ("CTG","L"), ("CTA","L"), ("CTC","L"), ("CTT","L"), ("CCG","P"), ("CCA","P"), ("CCC","P"), ("CCT","P"),
        ("CAG","Q"), ("CAA","Q"), ("CAC","H"), ("CAT","H"), ("CGG","R"), ("CGA","R"), ("CGC","R"), ("CGT","R"),
        ("TTG","L"), ("TTA","L"), ("TTC","F"), ("TTT","F"), ("TCG","S"), ("TCA","S"), ("TCC","S"), ("TCT","S"),
        ("TAC","Y"), ("TAT","Y"), ("TGG","W"), ("TGC","C"), ("TGT","C"), ("TAG","Amber/Stop"),
        ("TAA","Ochre/Stop"),("TGA","Opal/Stop")
]

Nucl = ["A", "T", "G", "C"]

stop = ["TAG", "TAA", "TGA"]

# %%
#rules:
# -1 = default
# 0 - 4 = exclude Nucleotide
def create_protein(seq_length, codon_excl, rule=-1, rand_pos_pick=-1, AminExcl=0): #AminExcl -# amino acids to exclude
    protein = []
    tmp = []
    Excl = [] # " "
    #if AminExcl == 1:
    #    Excl = DNA_codon_table[randint(1, 61)][1]
    tmp_table = DNA_codon_table[1:61]
    limit_table = []
    #print(tmp_table)

    if AminExcl > 0: # > 1
        #Excl = []
        for i in range(AminExcl):
            #print(len(tmp_table))
            tmp = tmp_table[randint(0, len(tmp_table)-1)]
            #while(tmp[1] in Excl):
                #print(tmp)
                #tmp_table.remove(tmp)
                #tmp = tmp_table[randint(0, len(tmp_table)-1)]
            Excl.append(tmp[1])
            tmp_table.remove(tmp)
            
    for i in range(1, 60):
        if(DNA_codon_table[i][1] not in codon_excl):
            limit_table.append(DNA_codon_table[i])
            
    #print("Amino Acid exclusion: ", Excl)
    triplet = limit_table[randint(0, len(limit_table)-1)]
    for j in range(0, seq_length):  #generating one specific protein sequence
        if(rule == -1):
            #protein.append(aminos[randint(0, len(aminos)-1)])  #DNA sequences
            if(rand_pos_pick > -1):
                if(rand_pos_pick == j):
                    protein.append(triplet[0])
                else:
                    protein.append(DNA_codon_table[randint(1, 60)][0])
            else:
                protein.append(DNA_codon_table[randint(1, 60)][0])
            
        else:
            tmp = DNA_codon_table[randint(1, 60)][0]
            #aminos[randint(0, len(aminos)-1)]
            while(Nucl[rule % 4] in tmp):
                tmp = DNA_codon_table[randint(1, 60)][0]
                #aminos[randint(0, len(aminos)-1)]
            protein.append(tmp)
    return protein, Excl, triplet[1]

# %%
def num_comb(val, codon_dict):
    pos_comb = 0
    for key, value in codon_dict.items():
        if value == val:
            pos_comb += 1
    return pos_comb

# %%
def find_comb(val, codon_dict, rule=-1):
    combs = []
    for key, value in codon_dict.items():
        if value == val:
            if(rule != -1):
                if(not Nucl[rule % 4] in key):
                    combs.append(key)
            else:
                combs.append(key)
    return combs

# %%
def create_sequences(protein, num_seq, rule=-1, rand_pos_pick=-1, rand_change=0):
    '''
        1. Protein sequence
        2. used_key lists for each amino acid
                           -OR-
           lists of possible key values for each key
    '''
    sequence = []
    tmp = []
    amino_list = []
    protein_len = len(protein)
    for i in range(0, protein_len):
        amino_list.append(False)
    amino_list[0] = True
    codon_dict = dict(DNA_codon_table)
    #print(codon_dict)
    seq_count = 0
    comb_dict = {}
    #comb_list = []
    for i in range(0, len(protein)):
        #print(codon_dict[protein[i]])
        combs = find_comb(codon_dict[protein[i]], codon_dict, rule)
        #print(type(comb_dict))
        comb_dict[i] = combs
        #comb_list.append(combs)
    #print(comb_dict)
    index = 0
    comb_tracker = [0 for i in range(0,len(protein))]
    #print(comb_tracker)

    while seq_count < num_seq:
        for i in range(0, protein_len):
            select = DNA_codon_table[randint(1, 60)][0]
            if i == rand_pos_pick:
                select = choice(comb_dict[i])
            tmp.append(select)
        sequence.append(list(tmp))
        tmp = []
        seq_count += 1
        
    #print(sequence)
    #print("amount of sequences: ", len(sequence))
        
    if rand_change > 0:
        rand_samples = randint(1, num_seq-1)  #alter rand_samples amount of sequences in protein class
        #print("rand_samples: ", rand_samples)
        for i in range(rand_samples):
            which_samp = randint(0, num_seq-1) #which seq to modify
            #print("Which samp: ", which_samp)
            for j in range(rand_change):   #which amino acids to modify
                loc = randint(0, protein_len-1)
                #print("location: ", loc)
                sequence[which_samp][loc] = DNA_codon_table[randint(1, 60)][0]
            
            
    return sequence

# %%
def create_set(num_aminos, seq_length, num_classes, seq_per_class):
    s = ""
    if num_aminos < 3:
        print("Need more aminos")
        return
    rand_aminos = []
    classes = []
    seq = []
    Excl = []
    codonExcl = []
    #for i in range(1, num_aminos-3): # -2 because of start and stop codons
    #    rand_aminos.append(DNA_codon_table[randint(1, 62)][0])  #looking at DNA

    for i in range(0, num_classes):  #generating diffferent proteins
        protein, tmp, CExcl = create_protein(seq_length, codonExcl, -1, rand_pos_pick=(seq_length-1))
        Excl.append(tmp)
        codonExcl.append(CExcl)
        print("protein ", protein)
        seq_list = create_sequences(protein, seq_per_class, rand_pos_pick=(seq_length-1))
        for j in seq_list:
        #    j.insert(0, "ATG")
        #    j.append(choice(stop))
            seq.append(''.join(j))
            classes.append(i)
            print(j)
            print()
        #print(type(seq_new))
        print("Finished class: ", i+1)
    #print(seq)
    print(codonExcl)
    return classes, seq, Excl

# %%
num_aminos = 64
seq_length = 50
num_classes = 19
seq_per_class = 500
keys, val, Excl = create_set(num_aminos, seq_length, num_classes, seq_per_class)
print(len(val))
#print(keys)
#print(len(val))
#list of tuples (x,y) where x is a string and y is index
fout = str(num_aminos) + '_' + str(seq_length) + '_' + str(num_classes) + '_' + str(seq_per_class) + '_rand_last'
print("data"+fout)
#for i in range(len(Excl)):
    #print("Amino Acid exclusion ", i+1, ": ", Excl[i])
with open('../data/data%s.csv' % fout, 'w') as f:
#with open('data/64_30_30_10.csv', 'w') as f:
    writer = csv.writer(f)
    writer.writerow(['class', 'sequence'])
    for i in range(0, len(keys)):
        #print("i: ", i)
        writer.writerow([keys[i], val[i]])
# Out:
# protein  ['CTG', 'TCG', 'CCA', 'CTT', 'CTG', 'TTC', 'ACG', 'TTA', 'CGG', 'GTG', 'CAA', 'GTC', 'ACA', 'GCA', 'CCG', 'GAT', 'AGG', 'TTC', 'ACG', 'TTG', 'ACC', 'AAT', 'GGC', 'AGC', 'CAT', 'TCG', 'CTT', 'CAG', 'ATA', 'TGC', 'GCG', 'TCT', 'AAC', 'AAG', 'CCT', 'CTG', 'TTT', 'GTG', 'CAG', 'AGA', 'ATC', 'CGA', 'ACA', 'CTT', 'GGA', 'GTA', 'TGG', 'GCA', 'AAT', 'GAT']
# ['TCT', 'ATT', 'GCG', 'TGG', 'ACG', 'GCT', 'TAT', 'TGC', 'TCA', 'TAT', 'TCG', 'CAA', 'ATT', 'TCT', 'TGT', 'CAT', 'GTA', 'GAT', 'GAA', 'GAG', 'AAG', 'CTC', 'TAT', 'TCC', 'CGT', 'CGG', 'TGC', 'GCA', 'CTA', 'GCC', 'GCG', 'GTA', 'GAC', 'AAA', 'GCA', 'ACG', 'ATA', 'GGC', 'AAA', 'GGT', 'GTG', 'CAG', 'AAA', 'TCC', 'GAG', 'GGG', 'CTA', 'CCA', 'GTG', 'GAT']
# ['CAT', 'CCC', 'ACA', 'AAG', 'AGG', 'TAT', 'ACG', 'GTC', 'ACC', 'TCC', 'ATC', 'AAG', 'TAC', 'CGA', 'GTT', 'TTT', 'ATT', 'TTT', 'GAC', 'AGA', 'AAT', 'CCT', 'ACA', 'CGA', 'TCA', 'CCT', 'GGT', 'CAC', 'CCG', 'GGC', 'CTT', 'CAA', 'TCC', 'TTC', 'TGT', 'ACG', 'CAA', 'GTA', 'TGG', 'GCT', 'GTA', 'TCT', 'CGA', 'TCA', 'TCC', 'ATC', 'TAT', 'ACG', 'GCA', 'GAT']
# ['TAC', 'GAT', 'AAT', 'GGA', 'GTC', 'CAT', 'GAA', 'GAG', 'AGA', 'AAT', 'GAC', 'GGT', 'GTG', 'TTC', 'TCG', 'GAG', 'CGG', 'CTG', 'ACT', 'CAA', 'CTG', 'CAG', 'GTA', 'CTG', 'ACA', 'TCT', 'AGG', 'GAC', 'CGA', 'GAG', 'TTA', 'AAC', 'GTG', 'GGG', 'GCA', 'GTA', 'TAT', 'GTG', 'ACA', 'CAT', 'TGG', 'GCG', 'CAC', 'ATA', 'AAT', 'CGC', 'TTA', 'GGT', 'CTC', 'GAT']
# ['GGA', 'AAT', 'TGT', 'ACC', 'TTG', 'CGT', 'CGA', 'CGG', 'GAG', 'GTA', 'TAT', 'ACT', 'CCC', 'TCC', 'TTA', 'AGC', 'GAC', 'ACG', 'GTG', 'AAA', 'GCG', 'GGT', 'TTG', 'TAT', 'TTA', 'TAT', 'TCT', 'ACG', 'AGA', 'CAG', 'AAT', 'ATC', 'TCC', 'TGT', 'GAC', 'AAT', 'ACG', 'GGG', 'TGC', 'AGC', 'TGT', 'TAC', 'GTT', 'ACC', 'CGA', 'GAG', 'GCA', 'CTA', 'GTA', 'GAC']
# ['GGT', 'GAC', 'GTA', 'CAA', 'CGA', 'ACT', 'AAC', 'GTC', 'GAG', 'GAC', 'TTT', 'CGG', 'ATC', 'CAC', 'GGG', 'TGG', 'AGT', 'TAC', 'ATT', 'GGG', 'GTG', 'CCT', 'CCA', 'CCG', 'GCG', 'GCG', 'GGT', 'TCA', 'AAA', 'GCC', 'CCG', 'TGT', 'AAA', 'AAA', 'AGA', 'GGG', 'ACA', 'CAA', 'ATC', 'ATT', 'GGA', 'AGT', 'TCT', 'CCA', 'GGA', 'CAA', 'TTT', 'GCG', 'TCT', 'GAC']
# ['TCA', 'CCC', 'TTT', 'TAT', 'TAC', 'TGG', 'CGC', 'CGC', 'TTC', 'CTT', 'AAC', 'TCC', 'GAA', 'CAT', 'TTT', 'AGG', 'TTT', 'CGC', 'CCC', 'TAT', 'CCT', 'TCA', 'GAG', 'AGT', 'TTT', 'AAA', 'GTC', 'AAT', 'ACC', 'GCT', 'ACG', 'GAC', 'GCC', 'AAT', 'GAA', 'AGT', 'TTG', 'TTT', 'ACG', 'CTA', 'CTG', 'CAA', 'GCA', 'TCA', 'GAT', 'TAC', 'AGA', 'GAG', 'TAC', 'GAC']
# ['GAT', 'CGC', 'TAC', 'TGC', 'TCA', 'CAC', 'CTG', 'AAC', 'CAA', 'CGT', 'CCA', 'TTC', 'TGC', 'CCC', 'GAG', 'CAA', 'ACC', 'GTA', 'CAA', 'CCT', 'AGT', 'CCC', 'TTG', 'TCT', 'CCA', 'CAA', 'CTA', 'AGA', 'CAC', 'GCT', 'ATT', 'GAT', 'AGG', 'CAT', 'AGA', 'TAC', 'TCA', 'AGT', 'GTC', 'CTC', 'TTC', 'GAG', 'CCG', 'CGC', 'GGT', 'TCA', 'AAT', 'AAG', 'TGG', 'GAT']
# ['ACT', 'GCG', 'ATT', 'GAA', 'CGA', 'TAC', 'TCA', 'GCC', 'AAT', 'CTT', 'GAG', 'ACG', 'CAT', 'CCT', 'ATA', 'TTT', 'TAT', 'TTC', 'CTA', 'GCG', 'ATA', 'TTG', 'AGT', 'TGC', 'TCA', 'TTA', 'GTA', 'CGT', 'CCC', 'GTG', 'CTT', 'TTC', 'TTG', 'AGC', 'GCG', 'GCA', 'TTG', 'GCG', 'AAG', 'TAC', 'TTC', 'CAT', 'AAC', 'TCT', 'CCG', 'TGC', 'TAT', 'TGC', 'ACT', 'GAT']
# ['TCG', 'AGA', 'ATC', 'TAC', 'AGG', 'ACT', 'TAC', 'CGT', 'TGG', 'GTG', 'GGG', 'TGT', 'GTC', 'GGG', 'AGG', 'TCT', 'ATA', 'GTA', 'AAG', 'CGC', 'GCA', 'CCT', 'CAG', 'AAT', 'CTT', 'AGG', 'CGC', 'AGG', 'ACG', 'GTG', 'CCG', 'CCT', 'TTA', 'GGA', 'GTG', 'TGC', 'ACT', 'CGT', 'TAT', 'TGT', 'TAT', 'GGG', 'ATT', 'ACT', 'CAC', 'AGC', 'TCT', 'ATA', 'TAC', 'GAT']
# ['TAC', 'ATT', 'GGG', 'GAA', 'TCG', 'GCC', 'TTG', 'GAC', 'GAA', 'AAG', 'ACT', 'GCC', 'TCA', 'TGG', 'TTA', 'GCT', 'CAG', 'TGT', 'CCA', 'TCG', 'TCA', 'GTA', 'GAG', 'GAT', 'GTG', 'CAA', 'CTA', 'TTT', 'CCC', 'ATA', 'CAA', 'AGT', 'TAC', 'AGG', 'AGC', 'AGC', 'ACG', 'AAA', 'TGC', 'TAT', 'CGT', 'GAG', 'TGT', 'CGA', 'CCC', 'ACT', 'AAC', 'CTA', 'GAG', 'GAT']
# ['AGA', 'GCG', 'TCG', 'CAG', 'GAT', 'GAC', 'GAA', 'GTT', 'AGA', 'ATC', 'CAT', 'ATT', 'GCT', 'CTA', 'GGC', 'AAT', 'GAT', 'AGT', 'AAC', 'TCA', 'GTA', 'GAG', 'AAA', 'CCT', 'AGC', 'GTC', 'AAT', 'TTG', 'TGG', 'AAA', 'ACC', 'CTC', 'AAC', 'TGT', 'GAA', 'GTC', 'GTT', 'CCT', 'CAG', 'AAT', 'GCG', 'CGC', 'GTT', 'CTA', 'GGG', 'TTA', 'GTC', 'GAA', 'TCT', 'GAC']
# ['GAT', 'CCT', 'TTT', 'CAT', 'ACA', 'TTA', 'ATC', 'CGG', 'ATT', 'GGT', 'CGA', 'TTA', 'CTG', 'CCA', 'TGT', 'TCT', 'TGG', 'TAC', 'CAC', 'ATA', 'TTA', 'GTG', 'ATC', 'CCA', 'TGT', 'CTG', 'TAT', 'AGA', 'ACT', 'CCG', 'ATT', 'GCA', 'GGT', 'GGG', 'CGA', 'GCA', 'AGT', 'ACA', 'GTG', 'GTC', 'ACA', 'GAC', 'GTT', 'TTA', 'TAT', 'CAT', 'CCG', 'ATT', 'GGA', 'GAC']
# ['CGG', 'TAT', 'GGA', 'GCG', 'ATA', 'CAG', 'TAT', 'TCG', 'CAT', 'GTC', 'ACT', 'TGG', 'TTT', 'CGC', 'ACT', 'TTG', 'ATC', 'CAT', 'TAC', 'AGG', 'CTT', 'GCT', 'GGG', 'CAA', 'TCC', 'GAA', 'TAT', 'CTA', 'TCA', 'GTC', 'TCT', 'CGC', 'ACG', 'TGT', 'TGT', 'AAA', 'TCA', 'GTG', 'GAC', 'CGA', 'CCA', 'TCG', 'GGT', 'GGC', 'CGT', 'GTC', 'CAC', 'GGG', 'CAG', 'GAC']
# ['ACT', 'GTA', 'AAG', 'TGT', 'TGG', 'ATT', 'CGT', 'GGT', 'CCA', 'TTC', 'ATT', 'GTC', 'AAC', 'TTT', 'GTC', 'CCA', 'AAG', 'CAC', 'ATC', 'GTC', 'CTA', 'CGC', 'GGG', 'TCA', 'ATC', 'ATT', 'CGC', 'TCA', 'GTT', 'GAC', 'AGG', 'TTA', 'GAG', 'TCT', 'GTC', 'CAA', 'CAA', 'GCA', 'CAT', 'AGC', 'AAC', 'CGA', 'GTG', 'AAA', 'AAC', 'CTG', 'GAC', 'CCC', 'CTA', 'GAC']
# ['AGC', 'ACT', 'GAT', 'TAC', 'TCC', 'TGT', 'CAC', 'GCT', 'GCA', 'GCC', 'TCA', 'GTG', 'TTT', 'TTC', 'AGT', 'GAA', 'ATT', 'CGG', 'TGC', 'CGT', 'AGC', 'ACG', 'GCC', 'GGG', 'CAC', 'CAT', 'TCT', 'ACC', 'TCG', 'CTG', 'AGA', 'GCC', 'ATA', 'TAC', 'TGT', 'ATA', 'CTG', 'CTC', 'TAT', 'CTC', 'GTC', 'CAG', 'GCA', 'ATA', 'CGG', 'AGC', 'AAT', 'GCG', 'ACG', 'GAC']
# ['CTT', 'GGT', 'GAG', 'ATC', 'GAC', 'AAC', 'GAA', 'AGA', 'CTT', 'CTT', 'GGA', 'ACC', 'CGC', 'TTG', 'ACA', 'AGA', 'AGT', 'TGG', 'TGC', 'TCC', 'AGG', 'ATA', 'GAA', 'TCG', 'CAA', 'TGG', 'GTA', 'CTA', 'TAT', 'ATC', 'GCA', 'AGT', 'GTT', 'AAT', 'CCA', 'AGG', 'ACT', 'GTG', 'GGA', 'TTG', 'GGA', 'ACT', 'CCA', 'AGG', 'CTG', 'AAG', 'ATT', 'TCT', 'GAG', 'GAC']
# ['TGG', 'TTG', 'TTG', 'TCG', 'AGG', 'CCA', 'CGT', 'GGG', 'ACC', 'TTC', 'ATA', 'ATC', 'CTC', 'CCA', 'CGC', 'GGG', 'CCA', 'TCT', 'GCT', 'GAG', 'TTC', 'GCT', 'GAG', 'AAT', 'AAT', 'GTA', 'ACA', 'TTG', 'ACA', 'CCA', 'AAG', 'GTG', 'ACT', 'CAT', 'CGC', 'GTG', 'GTT', 'GAA', 'AGT', 'CTC', 'CTT', 'ACG', 'CGA', 'ATA', 'GTA', 'GGT', 'GGT', 'GAG', 'ACT', 'GAT']
# ['GAA', 'CTA', 'CTC', 'CAG', 'CGT', 'TTC', 'GCA', 'CTA', 'TAC', 'AAG', 'AAA', 'ACC', 'CCA', 'TAC', 'AGT', 'GTG', 'GCC', 'TGC', 'AGG', 'TTC', 'ACA', 'AAT', 'TAC', 'ACA', 'GAA', 'ACA', 'AGA', 'TGG', 'CGG', 'CGC', 'TTA', 'CAA', 'TAC', 'CGA', 'GCA', 'AAT', 'ACG', 'CAT', 'GGA', 'ATA', 'CGC', 'GCA', 'ACC', 'TCG', 'ACG', 'TCA', 'GGC', 'GCG', 'GAC', 'GAC']
# ['ACT', 'TGT', 'ATA', 'CGA', 'CGT', 'CTA', 'AGA', 'CAT', 'ATT', 'CAC', 'CAA', 'TCG', 'GAG', 'AAC', 'AAC', 'ACT', 'ATA', 'AGT', 'AGC', 'TCA', 'AGG', 'CTT', 'GGC', 'GGT', 'GTC', 'CCG', 'GTA', 'TTT', 'GGT', 'CTA', 'ACA', 'ACC', 'ACC', 'CCC', 'CTG', 'ATC', 'TAC', 'AAC', 'GGC', 'ACA', 'GGA', 'CGT', 'TGC', 'CCT', 'ATT', 'TGC', 'TCA', 'AGT', 'CTG', 'GAT']
# ['TTA', 'CAA', 'GGA', 'ACA', 'TGC', 'GCG', 'TGT', 'TCT', 'CTA', 'CTA', 'AAC', 'CCT', 'TTT', 'TGG', 'AGG', 'TTC', 'CGA', 'ATC', 'AGG', 'GCG', 'CTG', 'TCA', 'GAC', 'ACT', 'GAT', 'CAT', 'TCT', 'CGA', 'TCT', 'GCG', 'TTT', 'CGA', 'AGT', 'CTC', 'GCT', 'CGC', 'GGA', 'ATA', 'CCA', 'CTG', 'AAG', 'TGG', 'GCC', 'GGC', 'GTG', 'CAC', 'TTA', 'CTG', 'TTT', 'GAT']
# ['AGG', 'TTT', 'GCG', 'CTA', 'CTA', 'GAG', 'GAA', 'TTC', 'CTT', 'CGC', 'GTC', 'TCC', 'CTA', 'GAA', 'AGG', 'GCG', 'TCA', 'TTC', 'TCG', 'CGG', 'GTA', 'AGA', 'CGG', 'CTT', 'GAA', 'ATT', 'GAA', 'TTA', 'AGG', 'GAA', 'AGC', 'AGG', 'TAT', 'ACA', 'TAC', 'CTG', 'GAT', 'CCC', 'GGA', 'AAC', 'ACA', 'TCG', 'ACG', 'CCT', 'CGA', 'CTG', 'TCA', 'TAC', 'CCG', 'GAC']
# ['CCA', 'TGT', 'CGA', 'TAT', 'AGC', 'GCA', 'GTA', 'TGG', 'CTG', 'AGC', 'CCC', 'CAG', 'CTG', 'ACC', 'TGC', 'AGT', 'TTA', 'TGC', 'CGT', 'CCG', 'CGG', 'TTG', 'ACG', 'TTA', 'ATC', 'GTG', 'GCG', 'CGA', 'AGG', 'ACA', 'CTG', 'CCC', 'GAA', 'GGT', 'ACC', 'ACC', 'ATA', 'CTC', 'AAC', 'ACG', 'TCA', 'GAG', 'GCC', 'CTG', 'AAT', 'GAC', 'GGG', 'AGC', 'CCT', 'GAT']
# ['AAC', 'ATA', 'CCG', 'CCT', 'TGC', 'GAA', 'AAA', 'AGA', 'CGC', 'GTG', 'CCT', 'AGG', 'TTC', 'AGA', 'CTG', 'TTG', 'CAG', 'TGT', 'GGT', 'CTC', 'TGT', 'GTA', 'GAG', 'GTA', 'AGT', 'AGC', 'CAC', 'ACT', 'ATT', 'CTA', 'CCA', 'CCT', 'GGC', 'AAG', 'TGG', 'CTT', 'GAT', 'ATA', 'AAA', 'GTA', 'CCT', 'ACG', 'CGC', 'AGA', 'TGC', 'CCG', 'CAG', 'GCA', 'AGC', 'GAC']
# ['GCG', 'AGC', 'GCC', 'GTC', 'CTG', 'TGC', 'GAA', 'TGC', 'CAA', 'GTA', 'CAT', 'CTG', 'GTC', 'TAC', 'GGA', 'GCT', 'CGG', 'CCC', 'GGT', 'TTG', 'AGA', 'GAA', 'GCG', 'AAA', 'TTT', 'CGG', 'CCA', 'ATT', 'ATC', 'GCC', 'ATT', 'CTG', 'CAT', 'CCT', 'CAG', 'AAA', 'TTA', 'CAG', 'CGA', 'CGC', 'TAC', 'TTT', 'ACT', 'GAT', 'TGC', 'CAA', 'AGC', 'TCC', 'CGA', 'GAC']
# ['AGT', 'TCC', 'GAT', 'TTA', 'CGG', 'CGC', 'TCA', 'GCG', 'CTC', 'ATC', 'GTT', 'TAC', 'CGG', 'GTG', 'TGC', 'GTG', 'AGT', 'TAC', 'GAA', 'GGT', 'GCA', 'ACT', 'TCC', 'ATT', 'TGT', 'CGA', 'CGC', 'GTG', 'TCA', 'ATA', 'ACT', 'TTC', 'AGC', 'CAT', 'CTG', 'TCG', 'GTG', 'AGC', 'CAT', 'GAA', 'GTC', 'TTT', 'CCT', 'ATT', 'GGG', 'GAC', 'GGA', 'AGA', 'AAT', 'GAC']
# ['CCC', 'TGC', 'AAC', 'TCC', 'CAC', 'CGC', 'CTT', 'GTC', 'AAT', 'TCA', 'AGC', 'GTG', 'GAC', 'CGT', 'GTT', 'GGC', 'ACA', 'AGT', 'TTG', 'CTA', 'CGT', 'AAT', 'CGT', 'CGG', 'CAT', 'TAC', 'AGC', 'TAC', 'CAG', 'TGT', 'CGC', 'AGT', 'CAG', 'AGA', 'TCC', 'ATT', 'TTT', 'GAA', 'CCT', 'TGT', 'TGG', 'TTT', 'CAG', 'GTG', 'CCA', 'AGG', 'TCC', 'AGA', 'CAC', 'GAT']
# ['TCT', 'TGT', 'GTT', 'CGT', 'ACC', 'CGA', 'GTG', 'CGG', 'CAC', 'TTT', 'GGT', 'TCG', 'AAT', 'AGG', 'CAG', 'TTC', 'CTG', 'TGT', 'ACT', 'GAA', 'ACG', 'CTT', 'TGG', 'CCC', 'GAA', 'ATA', 'TCG', 'TCT', 'ACC', 'GTT', 'TTC', 'CGT', 'ATC', 'AGT', 'AAG', 'TTC', 'AAC', 'CAC', 'TGC', 'AGT', 'GTT', 'AAT', 'TCG', 'CTC', 'CGC', 'GAA', 'GGG', 'AAA', 'CCC', 'GAT']
# ['AGT', 'TTA', 'AGA', 'GAC', 'TCG', 'AGA', 'GTG', 'ATT', 'CTG', 'TCG', 'GCC', 'AGG', 'AGG', 'ATT', 'GTA', 'GTC', 'TCC', 'TCT', 'ACA', 'CGT', 'TAC', 'CAT', 'ACT', 'AAA', 'AAC', 'CAG', 'AGG', 'GGC', 'CGA', 'GCG', 'GCG', 'AAC', 'CAT', 'ATC', 'GAT', 'TTT', 'GTT', 'GCA', 'ACT', 'CCC', 'ATA', 'GTG', 'GTG', 'CTT', 'ATT', 'GGA', 'GAA', 'CAT', 'ACC', 'GAC']
# ['GCA', 'TCA', 'GTA', 'TCT', 'GTC', 'ACA', 'GAC', 'GAC', 'GCA', 'GTC', 'CCT', 'AGG', 'CGG', 'CGT', 'ACC', 'AGA', 'GGA', 'AAC', 'TAT', 'GAC', 'GTA', 'CTG', 'AAC', 'TTT', 'TTT', 'GGA', 'CGT', 'AAA', 'TCT', 'ACC', 'CGC', 'GGT', 'TAT', 'CCA', 'TCA', 'AAG', 'ATT', 'GTC', 'CAG', 'CAT', 'GCA', 'AAA', 'TTG', 'GGT', 'CTA', 'GGC', 'TAC', 'ATA', 'ACG', 'GAT']
# ['GGT', 'CTG', 'CTC', 'ACT', 'TAC', 'TTG', 'TTC', 'GCG', 'GTC', 'ACG', 'ATC', 'AGG', 'TTC', 'ACG', 'ATT', 'GAC', 'GCC', 'AAG', 'AAG', 'GCG', 'CCA', 'ACC', 'TTA', 'TGG', 'CAC', 'CGG', 'ACG', 'GCC', 'AAA', 'CGA', 'GCT', 'GTC', 'GGA', 'CGC', 'TCA', 'TTC', 'TCA', 'CCC', 'TTT', 'AGT', 'AGT', 'GGC', 'GCG', 'GCG', 'AGA', 'AGC', 'GGT', 'CAG', 'CCC', 'GAC']
# ['TAT', 'CAA', 'GCG', 'GTA', 'ACC', 'TTG', 'TGT', 'GCT', 'GGG', 'GGG', 'CAA', 'TCC', 'TTG', 'GCT', 'CAA', 'AAC', 'GTA', 'CAG', 'TGG', 'GGC', 'AGA', 'TCG', 'ACA', 'ACA', 'AGA', 'CAA', 'TTT', 'TAC', 'TGG', 'GTA', 'ATT', 'ACA', 'CCG', 'TTA', 'GTT', 'TTG', 'TTA', 'AGA', 'TTC', 'CCC', 'TAC', 'TCA', 'GAC', 'GGC', 'GTG', 'TTG', 'GCA', 'TGG', 'CAA', 'GAT']
# ['TGG', 'TAT', 'GCA', 'GTT', 'GTC', 'CAT', 'AAA', 'AGC', 'TAC', 'CAG', 'ACG', 'CTT', 'ACA', 'CGA', 'ATC', 'CTG', 'CCT', 'CAA', 'ATA', 'GGG', 'ACG', 'AGG', 'GTG', 'CAT', 'TAT', 'CTA', 'CAT', 'AAG', 'CAT', 'GGT', 'CGG', 'GTT', 'TCG', 'TCG', 'TTT', 'CTA', 'AGT', 'TAT', 'ATT', 'AGT', 'CTC', 'GCC', 'TCA', 'CTA', 'TGC', 'CAT', 'AGA', 'CCA', 'AGA', 'GAC']
# ['ACT', 'CCA', 'CCG', 'AGA', 'TTG', 'TCT', 'TGG', 'AAT', 'ACA', 'AGA', 'TAC', 'CTT', 'TCG', 'TCT', 'TCA', 'AGA', 'CAT', 'CCG', 'CCA', 'CCG', 'ATA', 'AAT', 'ATC', 'GAC', 'TGC', 'AAC', 'GAT', 'GTT', 'TTT', 'ACT', 'GGG', 'ACG', 'AAA', 'AAT', 'GTG', 'ATT', 'GCT', 'AGA', 'CTC', 'TGC', 'CCC', 'GCT', 'CCG', 'CAG', 'AAG', 'GAT', 'CAC', 'ATA', 'AGA', 'GAT']
# ['GAT', 'TCA', 'AGT', 'AAC', 'CAA', 'GGT', 'TAC', 'ACT', 'CGA', 'TGG', 'AAC', 'CAG', 'GCA', 'CGG', 'GGG', 'AAC', 'AGC', 'TGC', 'CAT', 'TTG', 'ATC', 'GGA', 'TGC', 'CCG', 'CAA', 'GAA', 'CCA', 'CGT', 'CTA', 'GTA', 'CTA', 'TTT', 'CGT', 'GCG', 'AAA', 'CAG', 'GGG', 'GGG', 'TTT', 'GAG', 'CTT', 'GTA', 'CTT', 'GGT', 'ACC', 'CGC', 'TCA', 'CCC', 'CAT', 'GAC']
# ['GGG', 'TTC', 'CCT', 'GAA', 'TAT', 'TCT', 'GTA', 'GCA', 'TTG', 'ACA', 'TGG', 'TGG', 'TGT', 'CCG', 'GTT', 'CTT', 'GAT', 'AGT', 'GCT', 'CGT', 'ATA', 'GCA', 'TGG', 'ATC', 'ACC', 'GCC', 'AGT', 'GTT', 'CTG', 'CGT', 'CGT', 'GTG', 'GAA', 'TGC', 'CCT', 'AAA', 'AGT', 'TCG', 'GGT', 'ACG', 'TGG', 'CCG', 'CAA', 'ACC', 'CCA', 'AGC', 'AGC', 'CCA', 'TGG', 'GAT']
# ['CTG', 'AGG', 'TGT', 'GCT', 'GAA', 'CCC', 'ACT', 'GGA', 'TGT', 'ACG', 'ATC', 'ACG', 'TGG', 'CTA', 'CCA', 'GCG', 'CCG', 'GTT', 'AGG', 'CCA', 'TCA', 'ATA', 'AAG', 'TCG', 'ACT', 'CAC', 'GGT', 'TGT', 'AGC', 'CAC', 'CAC', 'CGA', 'CAC', 'AAC', 'CAA', 'AGC', 'CCA', 'TTC', 'GCG', 'ACC', 'CAC', 'CCC', 'GCC', 'CAC', 'CGA', 'CTC', 'GAC', 'TGT', 'AGG', 'GAT']
# ['GCA', 'GCA', 'TCC', 'CCT', 'GAC', 'GTC', 'AAG', 'CCC', 'GTT', 'TTC', 'GCC', 'AGA', 'CAA', 'CGT', 'ACG', 'GTT', 'CAT', 'TGT', 'TAC', 'CTA', 'TCT', 'GCG', 'AAC', 'ATT', 'ATT', 'ATA', 'CTA', 'ACA', 'CTC', 'ACA', 'CAA', 'CAC', 'GCA', 'CAA', 'CTG', 'TCA', 'CAG', 'CGC', 'TTT', 'AGT', 'CTG', 'ACA', 'CGC', 'GTA', 'ACT', 'TCA', 'AGC', 'GTC', 'AAC', 'GAT']
# ['CTC', 'CCT', 'TCA', 'GCC', 'TCA', 'AAG', 'ACA', 'TGG', 'CCA', 'GTA', 'GTC', 'GTT', 'CAG', 'CAA', 'TAC', 'ACG', 'ATC', 'TGG', 'GAA', 'CCC', 'TTA', 'TGT', 'ACT', 'CGA', 'CGA', 'AGT', 'CCC', 'ATC', 'AAG', 'ATC', 'CAA', 'GGA', 'GAA', 'CGC', 'AAG', 'TCC', 'GGT', 'TTG', 'TAC', 'CGT', 'CGA', 'GCC', 'CCA', 'TTG', 'AGA', 'TGC', 'TTT', 'GAC', 'ATC', 'GAT']
# ['TAT', 'TGT', 'CAA', 'TAT', 'GTT', 'GTC', 'CAT', 'TTC', 'TGC', 'GGG', 'AGT', 'CCA', 'ACA', 'GAT', 'CCT', 'TGC', 'GTC', 'ACC', 'GTG', 'ATC', 'TCC', 'GCC', 'AGG', 'CCT', 'TGT', 'AAG', 'CGG', 'AGA', 'CGA', 'ATA', 'CGA', 'GTG', 'CAA', 'CGT', 'GTA', 'TGT', 'CCG', 'ATT', 'TTC', 'TTA', 'GTA', 'CGC', 'GAG', 'CTT', 'TAC', 'GCC', 'GGG', 'TCC', 'CCT', 'GAC']
# ['TCC', 'GGT', 'CGC', 'TAT', 'GTG', 'TTT', 'GCC', 'AAT', 'AAA', 'CTC', 'TCC', 'CAT', 'GGC', 'TTG', 'AGG', 'GGA', 'TTA', 'CGG', 'GGC', 'AAT', 'TTC', 'AAA', 'ACG', 'ATC', 'CAG', 'GTG', 'TCG', 'ATT', 'GTG', 'CAG', 'CGG', 'TTC', 'CGT', 'TGC', 'ATA', 'AGA', 'GTA', 'GAG', 'AGG', 'CTT', 'CCT', 'AGA', 'CCT', 'TTA', 'ATA', 'GAG', 'CTT', 'AGG', 'AGG', 'GAC']
# ['AAC', 'AAA', 'GGC', 'CAA', 'TAT', 'GTG', 'GCG', 'CTG', 'GTA', 'GTG', 'TCG', 'ACG', 'CAT', 'AAT', 'TTG', 'ACC', 'GAT', 'GTA', 'CTT', 'TTA', 'GCT', 'GCG', 'CGA', 'CCT', 'CCG', 'AAG', 'GAT', 'GGC', 'GAA', 'CGT', 'AAC', 'CCT', 'AAT', 'GTA', 'GCG', 'CTC', 'CGT', 'GTC', 'GGT', 'TGC', 'TTA', 'GTC', 'ATC', 'TCA', 'CCG', 'ACG', 'GTA', 'GTT', 'TGT', 'GAC']
# ['ACA', 'GTC', 'GCA', 'CGC', 'AGT', 'CGC', 'TCT', 'GAC', 'GAG', 'TCT', 'GTA', 'TGT', 'CTT', 'CAC', 'AGC', 'GCT', 'GTC', 'TTT', 'CCA', 'GTC', 'TCA', 'TTC', 'CTG', 'ACA', 'GAA', 'GCC', 'AGG', 'GCT', 'CCT', 'AGG', 'GTG', 'CGC', 'ATT', 'GGC', 'AAA', 'TAC', 'ACT', 'TCC', 'GTC', 'ACG', 'CAC', 'GAA', 'TCA', 'CCC', 'CTG', 'AGG', 'GCA', 'AGA', 'AGT', 'GAT']
# ['GCT', 'GAA', 'CAG', 'GGA', 'CGA', 'TCC', 'CAC', 'TTC', 'CTG', 'CAA', 'GAA', 'GGT', 'GTA', 'GAG', 'CGA', 'AGT', 'ATC', 'TTA', 'CAC', 'TTC', 'CGC', 'TCG', 'TCG', 'CTA', 'GGT', 'GCC', 'TGC', 'TGG', 'CAC', 'CTG', 'TGC', 'CAT', 'AGC', 'ACT', 'GGC', 'AGA', 'GGG', 'GGA', 'GCA', 'ATA', 'CCA', 'CAG', 'GGC', 'CGG', 'TGG', 'TGG', 'CGG', 'GGC', 'TCT', 'GAC']
# ['ACT', 'TTG', 'GGT', 'ATA', 'AGG', 'AAT', 'TCG', 'GAG', 'TGG', 'GAT', 'TGG', 'GTA', 'CTT', 'CGT', 'TGT', 'CGA', 'CCA', 'GAT', 'TCG', 'ACG', 'CTC', 'AAA', 'AAA', 'GGA', 'TCA', 'CCG', 'GAA', 'ATC', 'TTC', 'TTC', 'TTT', 'AGT', 'AGG', 'AGT', 'ACG', 'AGT', 'GGT', 'AGC', 'GAC', 'ATA', 'TGG', 'TTC', 'CTA', 'GAC', 'GAA', 'CGC', 'AGA', 'AGA', 'GGC', 'GAC']
# ['GGG', 'TTT', 'GCA', 'ATT', 'CTA', 'GGA', 'CCA', 'AGT', 'CAA', 'GAA', 'CTT', 'CTA', 'TTA', 'TAT', 'TCT', 'AGG', 'GAA', 'TAT', 'TGC', 'CAC', 'TTC', 'GCC', 'CGC', 'CGA', 'CCC', 'AAA', 'CGC', 'CCT', 'AGA', 'CCA', 'AAG', 'CTT', 'TCC', 'ACT', 'TTT', 'AAC', 'CGA', 'CCA', 'CGG', 'GAA', 'GAG', 'CCG', 'AAG', 'TCC', 'CAC', 'TAC', 'CAG', 'TGT', 'GAA', 'GAT']
# ['CGG', 'ATC', 'GTG', 'ACA', 'CTC', 'CCA', 'ACC', 'GTG', 'ATT', 'CTT', 'CTA', 'GAT', 'ATC', 'TCC', 'CCC', 'GAC', 'CGA', 'GGT', 'AGT', 'GGG', 'CAC', 'CCG', 'ATA', 'CCG', 'GCC', 'TTG', 'TCG', 'GTT', 'CAA', 'TAT', 'CTG', 'GTC', 'CGA', 'CAT', 'GAA', 'GTA', 'GTC', 'AGA', 'ATT', 'GAG', 'AGT', 'TTT', 'ACA', 'GCG', 'CAC', 'CCC', 'CTG', 'TCA', 'TGG', 'GAC']
# ['CGT', 'TCG', 'CTT', 'GAC', 'CTC', 'TGG', 'CCC', 'TCC', 'GCT', 'CCG', 'AGC', 'CAC', 'AAA', 'GTC', 'GCC', 'AAA', 'TTC', 'TTC', 'AAG', 'AAC', 'ATA', 'CTT', 'AAC', 'ATA', 'GGT', 'GAG', 'GGT', 'CTT', 'ATA', 'ATC', 'GGG', 'ATA', 'AAA', 'ACT', 'TTA', 'GCA', 'TCG', 'TTA', 'TCT', 'GGA', 'AAA', 'TAC', 'GTT', 'ACT', 'TTT', 'CAC', 'GTC', 'TCT', 'CGC', 'GAC']
# ['CGT', 'TTA', 'GGC', 'CTC', 'ACC', 'AGC', 'AAC', 'ACT', 'AGG', 'TAT', 'AGC', 'GTC', 'GTG', 'GTG', 'TCC', 'CTT', 'AGC', 'ACG', 'CCC', 'CGC', 'CTC', 'GAG', 'ATC', 'GGC', 'CAC', 'TGT', 'GAT', 'GAT', 'TGG', 'AAT', 'GTC', 'AGT', 'GAA', 'GAA', 'CTT', 'ATT', 'GGT', 'TTA', 'AGC', 'CTG', 'CAA', 'GCG', 'GTA', 'TTT', 'GAA', 'TCA', 'TTC', 'TTA', 'ACA', 'GAT']
# ['TAT', 'TTC', 'GCC', 'AGG', 'GTT', 'TGG', 'CAC', 'ACT', 'ACT', 'ACA', 'TAT', 'TTA', 'TTT', 'AGA', 'CAT', 'GAG', 'AAT', 'CAT', 'TGC', 'CGC', 'CTT', 'AGC', 'ACG', 'GGC', 'GAG', 'TTC', 'CTA', 'ATT', 'CCA', 'CCC', 'CGC', 'AGC', 'CCG', 'AGA', 'ACG', 'CCA', 'ATA', 'GGT', 'ATT', 'TCT', 'GTT', 'AAC', 'GCG', 'ATT', 'GCC', 'AAA', 'TTA', 'AGC', 'TGT', 'GAC']
# ['GAG', 'ACC', 'ATA', 'CCT', 'CGA', 'TGG', 'TCA', 'GAA', 'CAT', 'AGC', 'GGG', 'GTA', 'GCC', 'TAC', 'CCT', 'TGC', 'AAT', 'CTC', 'GCG', 'GCA', 'GAG', 'AGT', 'AGT', 'TGC', 'GAG', 'GAC', 'CCG', 'GAT', 'CTC', 'CCC', 'AGG', 'AGT', 'AAA', 'AAG', 'CCC', 'AAT', 'TGT', 'CGT', 'ACG', 'CTG', 'CGC', 'AGA', 'ACG', 'GTC', 'CAA', 'ACA', 'CTA', 'CCA', 'AAG', 'GAT']
# ['CTA', 'ATA', 'GCG', 'ATT', 'GGT', 'AGT', 'GCC', 'TTC', 'ACC', 'CGT', 'GCG', 'GTA', 'GGA', 'AGT', 'AGT', 'TTG', 'TCT', 'TGG', 'GCA', 'TTC', 'AGT', 'AAA', 'ACC', 'TTC', 'TCG', 'GTC', 'TAT', 'TAT', 'ACC', 'GAC', 'AAC', 'CTT', 'CCA', 'TCG', 'GTT', 'ACT', 'AGT', 'TGC', 'TGC', 'ACA', 'CTC', 'ATT', 'CAT', 'AAT', 'GGT', 'CGA', 'GGA', 'AAT', 'GTG', 'GAC']
# ['TTG', 'AAA', 'GGA', 'CTC', 'AGG', 'CGA', 'TTA', 'AGC', 'TCG', 'ATT', 'TGT', 'GCA', 'CGG', 'ACC', 'TCT', 'TAC', 'AAC', 'ACG', 'ATA', 'CCA', 'CCA', 'GTA', 'CAC', 'CCA', 'ACC', 'TTG', 'TTG', 'TGC', 'CGT', 'TTG', 'CGG', 'TCG', 'CGT', 'TCC', 'GTT', 'AAT', 'GCG', 'GCC', 'CCC', 'GGC', 'CAC', 'CAG', 'AGA', 'CGC', 'TGG', 'CAC', 'GAA', 'GTT', 'TGC', 'GAT']
# ['TTT', 'CAG', 'GCA', 'GGC', 'GAC', 'GGT', 'ACG', 'TAT', 'GGC', 'GCA', 'CTA', 'CCT', 'TTT', 'TCG', 'TAC', 'CCG', 'GCC', 'TCT', 'CTA', 'CGA', 'TGT', 'GGG', 'CCA', 'CGG', 'GTT', 'GTC', 'CCG', 'TTA', 'TAT', 'TAC', 'ATT', 'AAG', 'AAC', 'CCC', 'CTC', 'AAC', 'ACG', 'AAC', 'ACA', 'CAT', 'ACG', 'TGG', 'GTT', 'GAG', 'GGC', 'GAC', 'GCA', 'CGA', 'GGC', 'GAT']
# ['GCC', 'TGG', 'TTA', 'AAC', 'CGC', 'GCT', 'ACC', 'TGC', 'GCT', 'ACA', 'AGT', 'GGA', 'TTG', 'GCA', 'ACG', 'AAA', 'CAC', 'AAC', 'TCG', 'GAA', 'TCA', 'CTT', 'CAT', 'ATA', 'GGC', 'TAC', 'GCC', 'ACA', 'AAT', 'CCT', 'GGA', 'TCA', 'CAG', 'TTG', 'GTA', 'TGG', 'TCT', 'GAA', 'CTC', 'TCT', 'GAA', 'GTC', 'GTA', 'GGA', 'GAT', 'GTC', 'CGC', 'ATC', 'GGG', 'GAC']
# ['AGC', 'TCT', 'GTA', 'TGC', 'AGG', 'TGC', 'GAA', 'TGG', 'TGG', 'TCG', 'CTA', 'ACG', 'CCG', 'TTT', 'GCC', 'ACT', 'GCC', 'GAG', 'CAG', 'ATA', 'TCA', 'TCT', 'GTT', 'CAT', 'TGG', 'ACA', 'GGA', 'TCT', 'GAT', 'GTT', 'ACC', 'GAT', 'CAT', 'GTC', 'CGG', 'AGA', 'GCA', 'GTG', 'TCG', 'TGC', 'CTG', 'TTC', 'CAT', 'CCA', 'CAG', 'TGT', 'AAG', 'CGT', 'TTA', 'GAT']
# ['TGG', 'GTC', 'CAA', 'TCG', 'CTA', 'GCA', 'TTC', 'GCG', 'CAA', 'ACC', 'AGA', 'CTA', 'GTA', 'ATA', 'AAT', 'GGT', 'ATA', 'CGT', 'TCC', 'GGG', 'GTG', 'GCC', 'TGT', 'AAA', 'GAG', 'CCA', 'CTA', 'GAC', 'GAC', 'AAG', 'TCT', 'GGA', 'AAA', 'CTA', 'GAA', 'GGT', 'CTC', 'CCG', 'CGG', 'ACA', 'AGA', 'CTG', 'AAT', 'TGC', 'CTT', 'TCA', 'GAC', 'CAG', 'GTA', 'GAT']
# ['GAA', 'ACC', 'AGA', 'GTC', 'TTT', 'CGA', 'CTG', 'TTC', 'TTA', 'CTC', 'CAT', 'CAA', 'CTT', 'TTG', 'TAT', 'CTG', 'AAG', 'ATC', 'TGG', 'CCG', 'ATT', 'TAT', 'CAA', 'GAA', 'GAA', 'GAT', 'GTG', 'TGC', 'TTA', 'GGA', 'TCT', 'CGC', 'CGG', 'TAT', 'ACA', 'CTT', 'CTA', 'GAC', 'ATC', 'GAT', 'AAG', 'CCG', 'TCG', 'TGC', 'GCC', 'CCA', 'TTG', 'GTT', 'ACC', 'GAT']
# ['ACT', 'GGA', 'TGG', 'TCA', 'ACA', 'GTT', 'CAC', 'AGA', 'CAG', 'AAA', 'AAA', 'GCG', 'GGC', 'TCA', 'GCA', 'GAT', 'GAT', 'GTC', 'ATA', 'TCC', 'AGC', 'TAT', 'CAA', 'AGG', 'GTC', 'TGC', 'ATA', 'AGG', 'TGT', 'ACA', 'CCG', 'CGT', 'GAG', 'ATT', 'GAT', 'TGC', 'GTG', 'ATC', 'AGA', 'ATA', 'CTT', 'CTT', 'ATA', 'TTT', 'CCA', 'GGC', 'CGG', 'GGG', 'GGA', 'GAC']
# ['CGT', 'TTC', 'ATT', 'TCC', 'GGA', 'GTG', 'GGT', 'CTC', 'CCC', 'GTC', 'GAT', 'GAA', 'TCT', 'CAG', 'TAC', 'CCT', 'ACG', 'GAG', 'ACG', 'TCG', 'GCG', 'CCG', 'GTT', 'TTT', 'CCT', 'ATA', 'CGT', 'TGG', 'AAT', 'AGT', 'AAC', 'CTG', 'TTA', 'TTT', 'GGT', 'TGT', 'CAT', 'TGC', 'TTA', 'CCA', 'TCT', 'CCG', 'GGA', 'CAT', 'CGT', 'CGT', 'ATT', 'CTG', 'CTT', 'GAC']
# ['GTA', 'GGC', 'GGG', 'CCT', 'AAG', 'ATT', 'TGT', 'ATT', 'AGC', 'ATA', 'TAT', 'GTA', 'AGC', 'TCA', 'GTG', 'GAA', 'AAT', 'CTG', 'AGG', 'AGA', 'AAG', 'GGG', 'GGT', 'CAG', 'CAA', 'GTC', 'TGG', 'GCT', 'CCC', 'CCG', 'CGC', 'CTT', 'TTA', 'TCG', 'ACG', 'TTG', 'GAG', 'CAC', 'CAA', 'GAC', 'CCC', 'TGC', 'CAT', 'AAG', 'CAA', 'ATA', 'GTG', 'CAC', 'CCG', 'GAT']
# ['CTA', 'CTC', 'TCA', 'AGC', 'TGT', 'CCG', 'GGG', 'TTG', 'CGA', 'ACG', 'CAC', 'ACC', 'ACC', 'GGC', 'CCT', 'GCA', 'CAA', 'GCC', 'TGC', 'TCA', 'GTA', 'CGA', 'TGG', 'TTC', 'GAC', 'CGC', 'CTA', 'TAT', 'AGG', 'ATT', 'CCT', 'CAC', 'GAA', 'ACG', 'AAG', 'ACG', 'CTC', 'TGG', 'CTG', 'CAC', 'CGT', 'GAC', 'TCC', 'ATC', 'ATA', 'AGA', 'GCC', 'GCG', 'CCA', 'GAC']
# ['AAT', 'GCC', 'GCT', 'TCC', 'ACA', 'GCA', 'CTT', 'GAC', 'AAT', 'GGG', 'ATC', 'CAA', 'TCC', 'GGA', 'TTT', 'CCT', 'GCC', 'GCC', 'GGA', 'TTA', 'CTG', 'TGT', 'ACC', 'AGA', 'ACG', 'CGC', 'ATC', 'GGA', 'TGG', 'TTT', 'GCC', 'AAG', 'AGA', 'ACC', 'ATC', 'AGG', 'TCA', 'CGC', 'CCC', 'GAC', 'AGG', 'CTC', 'AAA', 'GCG', 'CAA', 'CGG', 'CTG', 'TGG', 'CCG', 'GAT']
# ['ATA', 'AGA', 'TCG', 'CGT', 'CCG', 'TTC', 'CTT', 'AAC', 'TTA', 'AAC', 'CGA', 'TGC', 'CTG', 'ACT', 'GAT', 'ATC', 'GCA', 'TCG', 'AGG', 'ATC', 'AGG', 'CGT', 'CGA', 'TCA', 'CGG', 'TTA', 'TCG', 'CCG', 'CAC', 'GAA', 'CAG', 'GGC', 'TCT', 'GGC', 'CCG', 'CAA', 'GAG', 'GAC', 'CTG', 'GTT', 'GAG', 'CCG', 'TGC', 'TAT', 'CCC', 'TAC', 'ATT', 'CGT', 'TCT', 'GAT']
# ['GTT', 'CCC', 'GTC', 'GAG', 'ACC', 'TGC', 'AAG', 'TTC', 'GCG', 'TCT', 'TGG', 'CGT', 'AGG', 'AGT', 'GTA', 'CAA', 'GTT', 'TCC', 'ATC', 'CTA', 'ACG', 'GTC', 'GGC', 'TTA', 'ATC', 'CCG', 'AGG', 'ATA', 'CTT', 'GTC', 'GGA', 'GCT', 'GAA', 'ATC', 'TGG', 'CTA', 'GGT', 'CCA', 'TTC', 'TCC', 'GAG', 'GTT', 'GGC', 'CCG', 'CTG', 'AAT', 'GCA', 'CTG', 'CGA', 'GAC']
# ['ATT', 'AAT', 'TCA', 'GCT', 'CAG', 'ATC', 'TGT', 'TTT', 'GCT', 'ACC', 'ATT', 'TAT', 'ATA', 'GAG', 'AGT', 'CTG', 'GTA', 'AGC', 'TGC', 'GGA', 'CGG', 'GAT', 'AAA', 'ACG', 'GTA', 'CGG', 'ACT', 'AAG', 'TTG', 'GAG', 'AGT', 'TTA', 'GCG', 'GTT', 'TTA', 'GCA', 'CGT', 'ACA', 'CTG', 'GTG', 'GTT', 'ACA', 'CGC', 'TCC', 'AAT', 'CCG', 'CAC', 'GAA', 'GTA', 'GAC']
# ['CAC', 'TCG', 'ACC', 'CAA', 'TCC', 'CGA', 'ACT', 'TGC', 'CTC', 'CGA', 'GTA', 'AAG', 'CTA', 'TAT', 'TCG', 'GGT', 'AGC', 'AGC', 'GCT', 'ATT', 'GCT', 'ACA', 'ACG', 'CCG', 'GGG', 'AAG', 'CCC', 'TGC', 'AGC', 'GGA', 'CCA', 'CGG', 'TTT', 'ACT', 'TTC', 'ACA', 'GCT', 'CAG', 'TCC', 'CAC', 'GAC', 'CAC', 'GAA', 'ATA', 'ACG', 'TGC', 'ACT', 'GCT', 'AAA', 'GAT']
# ['CAC', 'GCC', 'TAT', 'GGC', 'GCG', 'CTG', 'TAC', 'ATC', 'AGG', 'ATT', 'GGA', 'AAG', 'AAA', 'TCC', 'ATA', 'CAC', 'TAC', 'TCC', 'CTT', 'TTC', 'CGT', 'AAT', 'AAT', 'ATC', 'GGG', 'GAA', 'AGG', 'AAT', 'CCA', 'TTA', 'ATC', 'AAG', 'GGT', 'ATA', 'CGT', 'CCG', 'GGG', 'GTA', 'CGA', 'GGT', 'CCT', 'GTA', 'GTA', 'CCT', 'ACC', 'ATT', 'GAA', 'GCG', 'TTA', 'GAT']
# ['AGA', 'AGT', 'GCC', 'GGA', 'ATC', 'CTG', 'GGG', 'GCC', 'AGA', 'GAT', 'GTA', 'TTT', 'AGG', 'GAT', 'ACT', 'AGA', 'ATA', 'AGA', 'AAC', 'GTG', 'ACA', 'CAG', 'CCA', 'AGG', 'ACA', 'AAA', 'TGT', 'GTT', 'ATT', 'TAT', 'CGT', 'TAC', 'ACA', 'CAC', 'CGA', 'CTA', 'CCT', 'ACC', 'GGG', 'ACT', 'ATT', 'AAC', 'CCG', 'CGA', 'CTT', 'GCC', 'GGC', 'GGT', 'GCT', 'GAC']
# ['GAC', 'GGG', 'ACA', 'CTA', 'GGT', 'AGG', 'AGG', 'TCA', 'GGT', 'GAA', 'GGA', 'CTA', 'TTT', 'CAT', 'GAC', 'AGG', 'ATC', 'GTA', 'CTG', 'ACA', 'GTT', 'GTG', 'CTG', 'GAG', 'TTC', 'CGA', 'CGC', 'CTT', 'AAC', 'TTC', 'GAT', 'GAG', 'TGG', 'CGT', 'GAA', 'GTG', 'CAA', 'GTT', 'GCG', 'TTG', 'AAT', 'CGC', 'CGT', 'CAT', 'TGG', 'ACC', 'ACG', 'AAG', 'GGG', 'GAC']
# ['TCT', 'GTG', 'AGG', 'AAT', 'CTA', 'TCT', 'GAC', 'GAT', 'GCC', 'TGC', 'TGG', 'AAT', 'ACT', 'TGC', 'CAT', 'CTC', 'GCC', 'AGA', 'TGG', 'GAG', 'CGA', 'GGC', 'CTT', 'CTC', 'GGA', 'TTA', 'AGT', 'AGG', 'AGA', 'CGA', 'CGT', 'AGC', 'TCA', 'AGA', 'ACG', 'GGG', 'CAG', 'TTA', 'ATA', 'TTT', 'ATT', 'AAT', 'TTC', 'AGT', 'TTT', 'AGG', 'GCC', 'AAT', 'AAT', 'GAC']
# ['TAT', 'AGG', 'GTT', 'CCA', 'TGT', 'ATT', 'GAC', 'TGC', 'AGT', 'CAT', 'ACC', 'TTA', 'CCG', 'AGA', 'AGC', 'GGC', 'GCA', 'ATC', 'GGT', 'GAC', 'ATC', 'GAC', 'TGG', 'GCT', 'TTA', 'CTA', 'ACC', 'TCT', 'AAT', 'CAA', 'CAC', 'TGG', 'GCC', 'ACA', 'CGC', 'GAG', 'TTA', 'CAG', 'AAG', 'AGA', 'GGT', 'CTT', 'GCC', 'CGA', 'GAT', 'AAT', 'TTT', 'CGT', 'ATC', 'GAT']
# ['CTA', 'CCG', 'CTA', 'AAT', 'CCT', 'CGT', 'GGT', 'TGG', 'TCC', 'TTT', 'TTA', 'CCC', 'AGA', 'GCA', 'GAT', 'GAA', 'GAC', 'GCG', 'CAG', 'GCC', 'AGA', 'CTG', 'ACT', 'TGT', 'TGC', 'ACA', 'GTA', 'TTT', 'TCA', 'GAT', 'TGG', 'GCC', 'ACA', 'AAC', 'TGC', 'TGC', 'CCA', 'TCG', 'CAC', 'CTT', 'ATA', 'ACG', 'ATC', 'TCG', 'CAC', 'TCT', 'TCT', 'GAC', 'AGA', 'GAC']
# ['CCG', 'AAT', 'GAC', 'CAC', 'CCC', 'GCG', 'GAC', 'GAC', 'TGT', 'TGC', 'CGC', 'GGG', 'TTA', 'CGT', 'AGG', 'CTA', 'CAG', 'AAA', 'CTC', 'ACA', 'GTC', 'CGG', 'CCA', 'GCT', 'GTA', 'AGA', 'AAT', 'GGA', 'GTA', 'GGA', 'ACA', 'GCC', 'TCC', 'CCG', 'AGT', 'TTA', 'GGA', 'GAG', 'AGA', 'GAG', 'CGC', 'TAC', 'TGG', 'GAC', 'CAC', 'TTG', 'GTC', 'GCT', 'GGT', 'GAC']
# ['CAA', 'GAT', 'GCG', 'ACG', 'GTT', 'GGT', 'AAG', 'TAC', 'CCA', 'GTG', 'TTT', 'CCC', 'GAG', 'TCG', 'GTA', 'GGG', 'AAC', 'GTA', 'ATT', 'GAT', 'TCA', 'CTA', 'AAA', 'AGT', 'TTG', 'GGC', 'CCG', 'AGG', 'GTA', 'CGA', 'TGC', 'CTT', 'GGC', 'CCA', 'ACA', 'GTC', 'TAT', 'TGG', 'GCT', 'CCA', 'GTT', 'AGG', 'TTT', 'CTC', 'TGG', 'TTC', 'AGG', 'GCC', 'AAA', 'GAT']
# ['CGT', 'GTT', 'TAT', 'CGG', 'CTC', 'TAC', 'TTG', 'AAA', 'TCT', 'GAG', 'ACA', 'AGC', 'CCT', 'CTT', 'CAA', 'CTC', 'CCA', 'AAA', 'AGA', 'CTT', 'GGG', 'GTG', 'ATC', 'GGG', 'ACC', 'GGG', 'TAC', 'CAT', 'ATC', 'CGC', 'GGT', 'TGG', 'CTG', 'CGT', 'AGA', 'CAT', 'TCT', 'GAA', 'AAC', 'GAT', 'AGT', 'TTC', 'GCA', 'ACC', 'AAG', 'TAT', 'GCT', 'ATC', 'AGT', 'GAT']
# ['TTC', 'ACG', 'GGA', 'GTC', 'GAA', 'TCG', 'CGG', 'TCT', 'CAC', 'TTA', 'GAT', 'GTA', 'CCG', 'TTG', 'TCG', 'ATT', 'CTC', 'GAC', 'GAA', 'AAC', 'AGA', 'GGG', 'TTA', 'TTC', 'TCA', 'CCC', 'AAT', 'TCT', 'GGT', 'TCA', 'GTG', 'GCA', 'TTC', 'TGT', 'AAA', 'ATT', 'CGG', 'CAT', 'TGG', 'TGG', 'CTC', 'TGG', 'ATC', 'GCA', 'TTG', 'GCT', 'TCA', 'CGT', 'CTT', 'GAT']
# ['ACC', 'CAT', 'CGA', 'TCT', 'GCA', 'AGG', 'ATC', 'CGT', 'AGG', 'TTT', 'GAC', 'GCT', 'GAT', 'ATT', 'CAA', 'TGG', 'TAC', 'TTG', 'CTC', 'CTC', 'CTG', 'AAA', 'CAT', 'AGA', 'GTT', 'AGG', 'TCT', 'AAG', 'GGG', 'CGA', 'CCT', 'CCA', 'ATT', 'CTT', 'AAG', 'AAT', 'AAC', 'AAA', 'AGG', 'TCG', 'CCA', 'TCG', 'GGG', 'AGC', 'CTT', 'TTT', 'GGA', 'CCC', 'GCA', 'GAT']
# ['GAG', 'GCG', 'AAG', 'CGC', 'AAG', 'ATC', 'CAC', 'GGC', 'TGT', 'GCA', 'AGA', 'CGT', 'TGT', 'CGA', 'TGC', 'GCC', 'CGC', 'AAC', 'CAA', 'TGG', 'GAG', 'TTG', 'TCG', 'AAA', 'ACA', 'GAG', 'ATA', 'CAA', 'CTC', 'TCG', 'CCC', 'CAT', 'GAA', 'ATA', 'AGT', 'TCG', 'ACT', 'TCA', 'GAT', 'CCC', 'ACG', 'AGC', 'TAC', 'CGG', 'CAC', 'GCT', 'GTC', 'TTA', 'ATC', 'GAT']
# ['AAT', 'GGC', 'GAC', 'GGC', 'CCG', 'TGC', 'GGA', 'TCG', 'AAG', 'CGA', 'GGC', 'GTG', 'CGT', 'CGT', 'TGG', 'AAA', 'CCT', 'TCG', 'AGA', 'TCA', 'TCC', 'GTT', 'AGC', 'CGT', 'CTA', 'TCA', 'CAG', 'GAC', 'GCA', 'CAA', 'ACA', 'CAA', 'TCA', 'TCG', 'GCC', 'TGG', 'AGC', 'TGG', 'ACG', 'GAT', 'GCG', 'ATT', 'CTT', 'GGA', 'GTA', 'GAC', 'TGG', 'TTA', 'CAC', 'GAT']
# ['TAT', 'CTT', 'TTT', 'TGG', 'CTC', 'CAT', 'AGA', 'ACC', 'ACA', 'CAA', 'TTA', 'TGC', 'ACG', 'CCT', 'GCG', 'ACG', 'AAA', 'GAA', 'CCT', 'ACA', 'CCA', 'GTT', 'ACC', 'GCT', 'GTT', 'TGG', 'AAG', 'GTC', 'GAC', 'ACT', 'ACT', 'GTA', 'CTC', 'GCA', 'ATT', 'CGG', 'CCC', 'GCT', 'AAC', 'CAG', 'ACC', 'CGA', 'GGG', 'TTG', 'TTT', 'ATT', 'GTT', 'TAT', 'GGG', 'GAT']
# ['TTT', 'CAA', 'ATT', 'ACA', 'CCG', 'AGG', 'TTC', 'CGT', 'GTC', 'CGC', 'TTA', 'ATC', 'GCC', 'CGC', 'AAT', 'AGA', 'GTT', 'AAG', 'AGT', 'AGT', 'CAC', 'CAT', 'CTA', 'AGC', 'CTG', 'ACC', 'GTA', 'CAA', 'TAT', 'TTT', 'AGA', 'GTT', 'GAA', 'TCA', 'ATA', 'TGC', 'CGA', 'AAT', 'TGT', 'AGA', 'TAC', 'GGA', 'CCT', 'TCG', 'ATA', 'GGC', 'CCG', 'GAC', 'AGC', 'GAC']
# ['GCG', 'AGG', 'CAC', 'CTC', 'CAG', 'ACT', 'TGC', 'GCC', 'CTG', 'ATC', 'GGT', 'TGG', 'CGC', 'CTG', 'CCT', 'CCG', 'TTC', 'CCT', 'AAG', 'TTG', 'ACC', 'TCG', 'CGA', 'AAC', 'TCA', 'CGC', 'CTA', 'GTA', 'AAC', 'AAT', 'CAG', 'CGA', 'AAA', 'GAT', 'TGG', 'GTC', 'CTG', 'ACT', 'CCG', 'ATC', 'TCT', 'GGA', 'GTA', 'ATC', 'TTG', 'CGT', 'GTG', 'GAA', 'GAG', 'GAT']
# ['CGT', 'ATA', 'ATT', 'GCA', 'GGG', 'AAT', 'GTT', 'CGC', 'AGC', 'CGG', 'CGA', 'AGG', 'CCC', 'GCA', 'TCT', 'GAT', 'TAT', 'AGG', 'AAG', 'TGC', 'AAT', 'GAG', 'ACA', 'AAT', 'CCG', 'CTA', 'GCC', 'CCC', 'CAG', 'TAC', 'AGC', 'TTG', 'CTC', 'GTT', 'CAT', 'TGG', 'TCC', 'CCA', 'CCA', 'TGC', 'GCA', 'ATA', 'CAT', 'CGT', 'CAA', 'GAC', 'AGG', 'CAG', 'TAC', 'GAT']
# ['GGT', 'CAG', 'TCT', 'GAT', 'AGG', 'CAC', 'GGC', 'GGT', 'TCC', 'TTG', 'CAG', 'AGA', 'ACG', 'TGG', 'GAT', 'GCT', 'GTT', 'GGG', 'GGG', 'GTC', 'AGA', 'GTC', 'AAC', 'CCT', 'GTT', 'TAT', 'TTC', 'CTT', 'CCT', 'GAG', 'GAA', 'CAA', 'CAT', 'AGA', 'TGT', 'TCG', 'ACG', 'CCC', 'ACT', 'CCC', 'ACC', 'TCC', 'CTA', 'GGG', 'GCC', 'TTC', 'GCC', 'AAT', 'GAC', 'GAC']
# ['TGT', 'TCT', 'ATT', 'TAC', 'ACA', 'GTA', 'CCG', 'GAA', 'CCG', 'CCG', 'TCA', 'CCC', 'CGA', 'TCC', 'GCC', 'GGG', 'AAG', 'GCT', 'GAC', 'CAT', 'CTA', 'GAT', 'CGC', 'ATC', 'TGC', 'TCG', 'TTG', 'ATA', 'AAG', 'TTT', 'ACG', 'GCA', 'TCA', 'CTT', 'ATT', 'TCG', 'TTC', 'CGC', 'CCC', 'ATT', 'TAT', 'AGC', 'TCA', 'TCT', 'TCC', 'ATT', 'CGA', 'CGG', 'CTT', 'GAT']
# ['TAT', 'CAC', 'ATA', 'GCT', 'CGG', 'CCA', 'TTG', 'GGG', 'CCG', 'AAC', 'GGG', 'AGA', 'TCT', 'TTT', 'CTA', 'GTC', 'ATT', 'ACG', 'GAT', 'GGT', 'CTG', 'TCG', 'ACT', 'GAC', 'CAC', 'CGA', 'GAT', 'CGC', 'GGT', 'CCA', 'TTA', 'ATC', 'TCA', 'AAA', 'TGC', 'TTT', 'AAA', 'TAC', 'AAG', 'GTC', 'AAT', 'ACA', 'GGT', 'AAT', 'CAT', 'TTT', 'AGG', 'TCC', 'GCC', 'GAT']
# ['GCA', 'ACT', 'TAT', 'TTT', 'CAG', 'CGA', 'GCC', 'CTC', 'GCT', 'ATC', 'CAA', 'AAA', 'TTT', 'GTT', 'GGT', 'CAT', 'TAC', 'CAG', 'GAT', 'AAT', 'GTC', 'CGA', 'CGT', 'ATT', 'TCG', 'TAC', 'TCT', 'TTA', 'CCG', 'TAT', 'TTG', 'AGG', 'ACC', 'CTC', 'CCC', 'TGG', 'AGC', 'AAT', 'GCG', 'CTG', 'CGG', 'GCT', 'CGC', 'AGG', 'GCG', 'TGC', 'GAG', 'TTA', 'ATT', 'GAT']
# ['GCA', 'GTG', 'CGT', 'GTG', 'TTT', 'AAC', 'GAG', 'CCG', 'GAG', 'GCC', 'GTT', 'GGA', 'CAG', 'CTC', 'TTG', 'TGG', 'TCT', 'GAA', 'ATA', 'CAC', 'TTT', 'AAC', 'CTT', 'GGC', 'ACC', 'GAC', 'GAG', 'CCG', 'TGT', 'GGG', 'TTT', 'CAG', 'GCC', 'GTG', 'ATT', 'CCC', 'CAT', 'CTC', 'CCT', 'AGA', 'TCG', 'ACA', 'GGA', 'GAA', 'TGG', 'TTG', 'CCC', 'CTC', 'TCC', 'GAC']
# ['GAT', 'GCA', 'AGC', 'GCG', 'TAC', 'ATC', 'GCC', 'TAC', 'CCC', 'AAT', 'GAC', 'CGT', 'ATT', 'ACA', 'TCA', 'AGC', 'GAC', 'GGA', 'GTA', 'CTG', 'GCA', 'AAA', 'TTC', 'AGA', 'GTT', 'CGA', 'TAT', 'GGC', 'AGG', 'AGG', 'TTG', 'CTA', 'ACG', 'TTT', 'CCC', 'GTG', 'TTA', 'ATA', 'ACG', 'TAT', 'AAT', 'GTC', 'ATA', 'CCG', 'ACT', 'AAT', 'GAA', 'AAG', 'TCT', 'GAT']
# ['CGT', 'TTG', 'CCC', 'GAA', 'CTC', 'GAC', 'AGA', 'CGT', 'TCT', 'CGA', 'TGT', 'AAA', 'TGG', 'TTA', 'GGC', 'AAC', 'CTC', 'CAT', 'ACT', 'CCA', 'TAC', 'ATT', 'CAT', 'CGA', 'ACA', 'TCG', 'GCT', 'AAG', 'TTC', 'CTG', 'TTA', 'TTA', 'GAA', 'CCC', 'CCC', 'GAC', 'ATC', 'AGT', 'CCA', 'AGG', 'TAC', 'GAG', 'AGT', 'ACA', 'CAG', 'CAC', 'TCC', 'ACG', 'ATC', 'GAT']
# ['GGA', 'GAG', 'ATT', 'GTG', 'CTG', 'CGC', 'TTT', 'TAC', 'AGA', 'CTG', 'CAA', 'ATC', 'AAG', 'CGT', 'AGT', 'AAA', 'ACT', 'GGG', 'CTT', 'GTG', 'TAC', 'TTA', 'GGC', 'GGA', 'GGT', 'GTC', 'GTG', 'CAA', 'AAG', 'ACG', 'GTC', 'TGC', 'TAC', 'CTC', 'AGG', 'ACA', 'CTA', 'AGT', 'CAG', 'GTC', 'CGC', 'ATA', 'ACT', 'CCG', 'ACC', 'CGT', 'AAC', 'GAG', 'ATC', 'GAC']
# ['GAT', 'CCG', 'ATT', 'CTC', 'TTA', 'TTT', 'ACT', 'TAC', 'GCG', 'GGC', 'AAA', 'AGG', 'TAT', 'CGT', 'GGG', 'ACC', 'GCA', 'TCA', 'TAC', 'TCA', 'CTG', 'GTT', 'ACT', 'TTG', 'AGG', 'GGA', 'CGA', 'CTG', 'AGT', 'CAT', 'TCC', 'TGC', 'CGG', 'GTT', 'CAT', 'GAC', 'TGC', 'GTT', 'GAC', 'GAC', 'ACA', 'ACA', 'CCA', 'CAT', 'AGC', 'AGA', 'AGC', 'CTT', 'GTC', 'GAT']
# ['TTG', 'TCT', 'TGG', 'ATA', 'CAA', 'GTC', 'TCA', 'TTA', 'GGG', 'CGA', 'TAC', 'CTA', 'CCG', 'CGA', 'TCG', 'AGG', 'GGC', 'GCA', 'CGG', 'TAT', 'AAT', 'TGG', 'TTA', 'ATA', 'AGC', 'AGG', 'CCC', 'TGT', 'AGC', 'TGG', 'GAT', 'ATA', 'CAA', 'GCA', 'ATT', 'GAG', 'AGT', 'ACT', 'ACC', 'TAC', 'GTG', 'CTT', 'TCT', 'TGC', 'AGT', 'AGT', 'CTC', 'GAT', 'GAT', 'GAC']
# ['CTG', 'GAG', 'CTA', 'GTT', 'CGG', 'GCC', 'GCT', 'CTT', 'GAA', 'ACT', 'TGC', 'GAT', 'GGA', 'TCT', 'TAC', 'GAC', 'TGG', 'GGT', 'GTA', 'CGC', 'CTT', 'CGA', 'TTA', 'GCC', 'AAG', 'GGA', 'GGT', 'CCT', 'GAC', 'CGG', 'ACG', 'ACT', 'GGG', 'AGA', 'TAT', 'CCT', 'TAC', 'AAG', 'AAG', 'CAC', 'AGC', 'AAT', 'AGG', 'CGA', 'GGA', 'AGA', 'CAC', 'CGG', 'AAC', 'GAC']
# ['TCT', 'CTT', 'TAC', 'CGA', 'GTG', 'TGG', 'AAC', 'AGT', 'CGG', 'AGT', 'CTT', 'ACT', 'TAC', 'CCG', 'TCC', 'ACC', 'ACT', 'GCA', 'ACG', 'CAT', 'AGG', 'GGG', 'GAT', 'GTA', 'GAA', 'GTT', 'ATC', 'CGT', 'TGT', 'GCC', 'CTA', 'GAG', 'TGC', 'AGT', 'CAT', 'AAG', 'TTG', 'AGT', 'AAC', 'GAG', 'AAG', 'TCG', 'ATC', 'CGG', 'AGG', 'ACG', 'CCA', 'ACT', 'TAC', 'GAT']
# ['CCG', 'TAT', 'TCG', 'TCC', 'ACC', 'AAG', 'GAA', 'TTG', 'GTC', 'GTA', 'GCG', 'AGA', 'CCG', 'TCG', 'CCC', 'TAT', 'CGG', 'GCT', 'TCG', 'AAT', 'GTA', 'ATC', 'CAT', 'GTG', 'GAT', 'TAT', 'CAG', 'AAC', 'TCT', 'ATC', 'ATC', 'CTC', 'GCA', 'CGC', 'TTC', 'GGA', 'CAA', 'TTG', 'CGG', 'AGC', 'TAC', 'TAT', 'GAA', 'CGC', 'TAC', 'TGC', 'TTG', 'GGA', 'TAC', 'GAT']
# ['TTT', 'GGA', 'ACC', 'GCG', 'GCG', 'TCT', 'GAC', 'ACG', 'GTG', 'ATA', 'CTA', 'GAT', 'AAA', 'CGG', 'ATA', 'AAT', 'AGC', 'ATT', 'CCA', 'CCT', 'ACT', 'AGA', 'CGT', 'ATA', 'CTT', 'TCT', 'ACC', 'TCT', 'GCC', 'CCT', 'CTA', 'CGG', 'CCC', 'TTG', 'TTG', 'AGT', 'CCT', 'GAG', 'AGT', 'GGC', 'AAT', 'TCG', 'GTT', 'GCG', 'GCT', 'ATC', 'TTT', 'TGT', 'CGT', 'GAC']
# ['GGC', 'GTC', 'AAC', 'GCG', 'TCT', 'TCT', 'AGT', 'TCA', 'ATA', 'TAT', 'ACT', 'TAC', 'TGG', 'AGA', 'CCA', 'AAC', 'CCG', 'CCA', 'AGG', 'AGT', 'GTT', 'CAC', 'TCT', 'GGC', 'GCG', 'AGG', 'CTC', 'AAG', 'CAC', 'GCA', 'CGC', 'ACG', 'CAG', 'CCT', 'GAC', 'CAC', 'GGC', 'CTG', 'TAT', 'CCT', 'TGG', 'GTT', 'GCC', 'CAT', 'TGG', 'TCG', 'TTT', 'GGC', 'AGA', 'GAT']
# ['ATT', 'TGT', 'GCA', 'ACC', 'GCA', 'ACG', 'CAT', 'CAC', 'CGT', 'AGA', 'GCG', 'GGA', 'ACT', 'GAG', 'AGG', 'CGA', 'GTC', 'GAC', 'CAA', 'CGG', 'GTG', 'TTC', 'GAT', 'CAT', 'CTT', 'CAA', 'TAT', 'TTG', 'TTG', 'CAG', 'AAG', 'ATT', 'CTA', 'GTC', 'GTA', 'TTC', 'TAT', 'GGA', 'CAT', 'AAT', 'TGC', 'CGT', 'GGC', 'TCC', 'TTG', 'AAG', 'TGG', 'ACA', 'GGG', 'GAT']
# ['CTC', 'GGA', 'CGC', 'TCG', 'GTT', 'AGA', 'TCC', 'ATT', 'CCG', 'GCA', 'GAA', 'GAG', 'CGT', 'CCT', 'CGG', 'AAG', 'TCT', 'GGC', 'ACT', 'AAA', 'CTA', 'AAT', 'CCA', 'ACC', 'GTA', 'GTT', 'AAT', 'CAC', 'TTC', 'GCC', 'GTT', 'ACG', 'GGC', 'TAT', 'CAT', 'ACG', 'ACC', 'TCT', 'TAC', 'GAC', 'GGT', 'GGT', 'GCA', 'AAC', 'TTG', 'CAT', 'TGG', 'GCC', 'GAC', 'GAC']
# ['ACG', 'GCC', 'CAT', 'CTT', 'GGC', 'ACG', 'GTG', 'AGC', 'TTG', 'TCG', 'CCT', 'ATC', 'TCA', 'AAG', 'ACA', 'CGA', 'TCT', 'CTG', 'CGA', 'ATC', 'GGG', 'ATT', 'ATA', 'GCC', 'ACC', 'GCA', 'AGT', 'AGG', 'TTC', 'CGA', 'CCT', 'CTA', 'CGA', 'CGC', 'CGC', 'TTG', 'TGG', 'CGC', 'GGC', 'CTG', 'GCG', 'CCG', 'TTG', 'TCC', 'CCC', 'GCT', 'GCG', 'AAC', 'GCG', 'GAC']
# ['CCT', 'GCT', 'GTC', 'AAG', 'TGC', 'TCC', 'GGG', 'AAC', 'CGG', 'CGA', 'TGG', 'GGC', 'GGG', 'GCT', 'TAT', 'ACC', 'TCC', 'AGA', 'TAT', 'CAG', 'CAA', 'GTG', 'GAG', 'CAC', 'GCG', 'TGG', 'CTC', 'CCT', 'GCG', 'GCG', 'GCA', 'AGA', 'CCG', 'CAT', 'CCG', 'AAG', 'GCC', 'CGC', 'GCA', 'TCT', 'GCC', 'GAG', 'AGG', 'TAT', 'TGG', 'ACC', 'GTA', 'TCT', 'ACT', 'GAC']
# ['CTT', 'AAG', 'GTC', 'GGT', 'CCG', 'TTG', 'CCG', 'TCC', 'CTA', 'AAG', 'CTG', 'GAG', 'AGC', 'AGT', 'GGC', 'TCT', 'GGG', 'TAC', 'AGA', 'GTT', 'TTT', 'CAG', 'TAT', 'TTA', 'TAT', 'CTC', 'CTC', 'GCG', 'TGT', 'GAA', 'CGG', 'TGT', 'AGA', 'CTT', 'AAA', 'GCT', 'ACA', 'ACT', 'CTT', 'TGT', 'GGT', 'ACT', 'AAT', 'AGC', 'CGA', 'CTG', 'AAA', 'CCA', 'TTC', 'GAC']
# ['TCA', 'GTT', 'TCA', 'GAC', 'TGG', 'CAA', 'CGA', 'GTG', 'GAT', 'TTA', 'TTA', 'CTG', 'GGC', 'CTG', 'ACA', 'CAG', 'TGG', 'CGA', 'ACA', 'CTT', 'CGA', 'CCG', 'GGC', 'AAT', 'AGT', 'GAA', 'CCC', 'GAA', 'GAC', 'CTG', 'CAC', 'GAG', 'ATC', 'CTT', 'GAC', 'TGG', 'GAC', 'ACA', 'CAT', 'ATC', 'ATT', 'CAC', 'CGT', 'GAC', 'AAT', 'CTT', 'ATA', 'TCT', 'ATT', 'GAC']
# ['ACT', 'CTC', 'TCT', 'GGA', 'GAA', 'TTA', 'CCT', 'CCA', 'GTT', 'CTC', 'TCT', 'TGG', 'TTA', 'CTT', 'AAT', 'GCC', 'GTG', 'TAT', 'TCG', 'AAC', 'CCA', 'GGT', 'GTG', 'TTG', 'CAC', 'GAG', 'AAA', 'GTA', 'ACG', 'CTC', 'CAG', 'CTA', 'CAA', 'GGA', 'GGT', 'AAG', 'TAT', 'AGG', 'ACC', 'GAG', 'TGT', 'AAT', 'GCA', 'TCG', 'AGT', 'CCA', 'TGT', 'ACC', 'TCC', 'GAC']
# ['TAC', 'CTT', 'TGT', 'TAT', 'TGG', 'CTG', 'GTC', 'TCC', 'AGT', 'AAA', 'CTA', 'ACC', 'TAT', 'CGT', 'ATA', 'ATA', 'GTT', 'GCA', 'CAA', 'TCC', 'CGT', 'TTT', 'TCT', 'CGA', 'TTG', 'CGA', 'AAC', 'GGC', 'GCT', 'TGC', 'CCC', 'CGA', 'ACT', 'ACT', 'CCC', 'AGC', 'TTT', 'CGC', 'CGT', 'GGT', 'GCT', 'AGT', 'CAT', 'GAC', 'AAA', 'AGT', 'AGG', 'CTC', 'GCC', 'GAT']
# ['GTT', 'GCC', 'AGG', 'GCG', 'CCG', 'CGC', 'ATC', 'TTC', 'GAA', 'ACC', 'CTT', 'CGT', 'TGG', 'ACG', 'ACC', 'CAG', 'CGG', 'CCT', 'GAT', 'TTT', 'GAG', 'AAT', 'CCT', 'ACG', 'TAT', 'CAG', 'TCC', 'GTC', 'GCA', 'TCA', 'GCG', 'TTA', 'CCC', 'AAT', 'CAC', 'TAC', 'CCG', 'ACA', 'ATT', 'GCG', 'TAC', 'ACT', 'TAC', 'GAG', 'AAG', 'GGG', 'GCC', 'GCA', 'GGG', 'GAC']
# ['CTA', 'GCT', 'AAC', 'AAG', 'GGT', 'CGT', 'CGA', 'TTG', 'CGC', 'AGG', 'CCA', 'AAT', 'GCT', 'CTT', 'TCG', 'TCA', 'CTT', 'GAG', 'TTT', 'GCA', 'TCC', 'CTC', 'CCA', 'CTG', 'CAA', 'TGT', 'GCA', 'TGC', 'ACG', 'TAC', 'GAG', 'GAG', 'CCC', 'AAC', 'ATT', 'TGC', 'GAG', 'ACA', 'GTC', 'TTC', 'TTG', 'TCG', 'CGT', 'TTC', 'TGG', 'TGT', 'CTT', 'CTG', 'GTG', 'GAT']
# ['GCC', 'TTG', 'GCA', 'TTG', 'TGT', 'GGC', 'CTT', 'TCA', 'CGC', 'AAG', 'AGC', 'GAG', 'GTG', 'AAC', 'AAG', 'GGC', 'ACA', 'GAA', 'GCT', 'CTC', 'CAG', 'TTT', 'ACT', 'GTG', 'TTG', 'CGG', 'CTG', 'TTA', 'TTG', 'TCG', 'TCG', 'CAA', 'AGT', 'GCT', 'TCA', 'ACT', 'ACG', 'TGT', 'AAT', 'GTG', 'CAT', 'GAT', 'GCA', 'ACA', 'GCG', 'GCG', 'CCT', 'CAC', 'GAA', 'GAC']
# ['CAG', 'TAC', 'GTA', 'TCA', 'GGA', 'GGA', 'TTG', 'AGA', 'GGG', 'ATC', 'CTC', 'AGA', 'TTT', 'GCG', 'GGA', 'CAT', 'ATC', 'GGA', 'GCT', 'CCA', 'TCT', 'CGG', 'GTG', 'TGG', 'CGG', 'GCC', 'AGT', 'ACT', 'AGT', 'CCT', 'AAT', 'CCC', 'GCA', 'GCG', 'GTG', 'ACC', 'CAC', 'AGA', 'AAA', 'TAT', 'GAA', 'GTA', 'CCT', 'GCG', 'CGA', 'TCA', 'CCG', 'TTG', 'TTA', 'GAT']
# ['TCC', 'CCT', 'ATA', 'GCC', 'GGT', 'CAC', 'AAA', 'TAC', 'GTT', 'ATT', 'TTG', 'GTT', 'TAC', 'ATC', 'GGT', 'CCA', 'ACG', 'TTG', 'AGT', 'GAG', 'GGG', 'CAC', 'AAT', 'AAC', 'AGA', 'TTA', 'TTA', 'GCT', 'GCG', 'GTG', 'GCC', 'CCA', 'GCG', 'ACT', 'AGT', 'CTC', 'AGA', 'CTT', 'AGT', 'TGT', 'AAT', 'ACG', 'CAT', 'TCG', 'ACC', 'GTT', 'GAT', 'TGG', 'TTG', 'GAT']
# ['TCT', 'TTA', 'ATC', 'GAC', 'GGT', 'GCG', 'CAT', 'GCA', 'GCT', 'TGT', 'GTT', 'TGG', 'GGG', 'TCT', 'ACC', 'GGA', 'TGT', 'TGT', 'TGC', 'AGC', 'ACT', 'TTT', 'TCG', 'CAT', 'ATC', 'GTA', 'CAT', 'GCC', 'TCA', 'GTT', 'TTT', 'TGC', 'CTA', 'TCG', 'TTC', 'GCA', 'ATT', 'CAG', 'CCC', 'CGA', 'TCG', 'TTA', 'TGC', 'GTT', 'CAC', 'ACG', 'ACT', 'TTC', 'TCA', 'GAT']
# ['CGT', 'ACA', 'CTT', 'TCG', 'AGG', 'AAC', 'CCA', 'CAT', 'GTT', 'GCA', 'TAC', 'CGT', 'GAT', 'CAT', 'ACG', 'TCA', 'ACC', 'CAT', 'CTT', 'GCT', 'GTA', 'ACA', 'CCT', 'CAG', 'TCT', 'ACT', 'CAG', 'AAC', 'GGG', 'CTA', 'GGG', 'AAA', 'CAA', 'TCC', 'ACC', 'CAC', 'CCC', 'CAC', 'TCG', 'TTC', 'CTG', 'CTG', 'TCC', 'CGA', 'TGC', 'ACC', 'GGC', 'CGA', 'GTG', 'GAC']
# ['AGC', 'ATC', 'GGA', 'CCG', 'TGC', 'CGC', 'CAA', 'ATT', 'TGG', 'ACA', 'CGC', 'GGA', 'CAC', 'CTG', 'TTT', 'TGG', 'GGG', 'GTG', 'TGG', 'GCG', 'CAC', 'CGG', 'AGT', 'ACA', 'GTA', 'CAA', 'GAC', 'TGG', 'GCT', 'TAT', 'GGA', 'GCG', 'AGG', 'AAG', 'GCA', 'TTT', 'TGG', 'CTA', 'ACC', 'TGG', 'TAC', 'TAC', 'AGA', 'ATT', 'GTT', 'CGA', 'CGA', 'CCT', 'TCT', 'GAC']
# ['GGC', 'AGC', 'CGA', 'GCC', 'TTC', 'CTC', 'GGT', 'GTG', 'GGG', 'GGC', 'AAA', 'GGT', 'ACC', 'CAG', 'CTA', 'TGC', 'ACT', 'CCT', 'AAC', 'GCT', 'CAC', 'AGC', 'CGA', 'ACG', 'GCA', 'TTC', 'GCG', 'ATT', 'TTG', 'GAG', 'GCG', 'AGC', 'ACC', 'TTC', 'CAT', 'TGG', 'GTA', 'ATC', 'TTC', 'GTT', 'TGC', 'GCG', 'AGT', 'CCC', 'TTT', 'AGT', 'CAT', 'GCC', 'CTG', 'GAC']
# ['TCG', 'CAG', 'GAA', 'CAG', 'GCC', 'AGC', 'AAA', 'GAA', 'CTT', 'CAC', 'GCC', 'CTT', 'CGC', 'TCA', 'GAC', 'CAT', 'TGC', 'ATA', 'CGT', 'AAA', 'ATT', 'GTA', 'TCG', 'GAT', 'TAC', 'AGC', 'AGC', 'CCC', 'GTC', 'GTG', 'CTA', 'CTA', 'GTG', 'TTA', 'AGC', 'GCA', 'GTG', 'ACC', 'GTC', 'ACG', 'CCA', 'CTA', 'AAA', 'TGG', 'GCT', 'AGA', 'GCT', 'GAG', 'CAA', 'GAC']
# ['CGA', 'CAA', 'ACG', 'GTA', 'CTT', 'AGA', 'TCA', 'GTC', 'GCG', 'GCG', 'TAC', 'GTT', 'CAT', 'AAA', 'CTC', 'GCT', 'GAC', 'TCC', 'CTA', 'TGT', 'GTC', 'ACA', 'CTC', 'TAT', 'AGT', 'GTG', 'ACT', 'TTC', 'CCA', 'GTG', 'CTT', 'TGT', 'CAC', 'CCC', 'ACT', 'CAT', 'ACA', 'CCG', 'CTT', 'CTC', 'AAG', 'GAG', 'AGC', 'TTC', 'TGT', 'AAA', 'GCC', 'GCC', 'ATA', 'GAC']
# ['CGC', 'ACG', 'CGC', 'TAT', 'CCC', 'ATT', 'GCC', 'CAG', 'AAT', 'CCC', 'CGG', 'TGT', 'GTA', 'ATC', 'AAA', 'TTG', 'GAC', 'CCC', 'AGG', 'GAA', 'AAC', 'CTC', 'ATA', 'ATC', 'CCC', 'GAG', 'ACA', 'GCG', 'CGG', 'TGC', 'CTA', 'TCG', 'GAA', 'CAC', 'TGC', 'TAT', 'CGG', 'GCT', 'ATT', 'TCG', 'TGT', 'GTT', 'GAC', 'GTG', 'CCC', 'GGC', 'CAT', 'CCG', 'CCA', 'GAC']
# ['CAC', 'AGA', 'CTC', 'GAA', 'CAG', 'ATA', 'TAC', 'GTA', 'TGG', 'TTC', 'ACT', 'CAT', 'CGA', 'GCA', 'GAA', 'TTC', 'CCT', 'TAT', 'CCT', 'CCT', 'GCT', 'GGA', 'GTA', 'CAG', 'AGC', 'GGC', 'CTA', 'ATC', 'CCC', 'GTC', 'CTG', 'ACC', 'GTC', 'GAA', 'CGG', 'CCA', 'CAA', 'CGG', 'GCT', 'AAA', 'CGC', 'CAT', 'CGG', 'CAG', 'GTC', 'ATC', 'TAC', 'ACA', 'CTA', 'GAT']
# ['CCG', 'ACC', 'CAC', 'CGC', 'GGT', 'ACA', 'GTA', 'GGA', 'GCA', 'GCT', 'CGA', 'CGG', 'GTT', 'TCC', 'TTC', 'ATT', 'CGC', 'CGG', 'TTG', 'AGA', 'CCG', 'CGG', 'AGG', 'GGG', 'TAT', 'GGC', 'AGA', 'TGG', 'TGT', 'AAC', 'GAA', 'CCC', 'GTG', 'CTT', 'AAC', 'GTG', 'TCA', 'AAC', 'ATC', 'CGT', 'CTG', 'ACC', 'CGA', 'TAC', 'CTG', 'TAC', 'TTG', 'GGG', 'CGT', 'GAT']
# ['TAT', 'GGT', 'GCA', 'CAG', 'TAT', 'ATC', 'GAG', 'TCG', 'TTG', 'TAC', 'GAC', 'CGG', 'CGC', 'CGG', 'TTC', 'AGA', 'GTT', 'AGC', 'GAA', 'CAA', 'CGA', 'AGG', 'ACC', 'TTT', 'CCG', 'AAC', 'TCG', 'GTG', 'CTG', 'AGT', 'AAG', 'AGT', 'ACA', 'GCC', 'TCG', 'CCG', 'GAA', 'CAT', 'TCC', 'CGG', 'GCT', 'AGA', 'ACG', 'AAA', 'CTG', 'ACC', 'GGC', 'ACA', 'AAG', 'GAT']
# ['TCC', 'CGG', 'ACA', 'ACA', 'GCG', 'GCA', 'CCT', 'CGC', 'ACG', 'CTG', 'TTT', 'GTT', 'AAT', 'AAA', 'ACT', 'TGT', 'GAG', 'CAG', 'CGC', 'TCC', 'GAG', 'GCC', 'GAC', 'TGG', 'TCC', 'TTA', 'TCG', 'ACA', 'TGC', 'AAG', 'GTA', 'GCT', 'GCA', 'CGC', 'CGA', 'GTT', 'CAC', 'GCT', 'TGC', 'TGT', 'AGC', 'TTA', 'CCT', 'TCT', 'AAG', 'TAT', 'GCT', 'ATT', 'CTT', 'GAC']
# ['CCT', 'TTA', 'GCT', 'CGA', 'GCT', 'CCG', 'GTG', 'TAT', 'TAT', 'TTC', 'GTC', 'GCC', 'AGC', 'TAC', 'CAA', 'CGT', 'ACT', 'GTC', 'GCT', 'CAA', 'TTG', 'CCG', 'GCT', 'CTG', 'CTT', 'TCG', 'CTC', 'CCT', 'TTT', 'GTT', 'TCC', 'ACA', 'TAC', 'TCG', 'CAC', 'GGA', 'AAA', 'CGA', 'GAG', 'GCT', 'CAA', 'GAA', 'GGT', 'GAT', 'AAT', 'TGC', 'GCT', 'AAA', 'CTT', 'GAT']
# ['CGT', 'GAG', 'AGA', 'AAC', 'GAT', 'GAT', 'GCC', 'GCC', 'CTG', 'GGC', 'GCA', 'TTA', 'GTC', 'GGC', 'TCG', 'GCC', 'GAG', 'AAG', 'GTC', 'ATT', 'GAA', 'GAT', 'AGA', 'GAT', 'ATT', 'TGT', 'GAG', 'GTG', 'CGA', 'GGG', 'GAA', 'TCC', 'ACC', 'AAT', 'CGA', 'CCA', 'GGT', 'CGG', 'AAA', 'GCT', 'GAG', 'AGG', 'GGG', 'GCT', 'GCC', 'CCG', 'CTC', 'CGG', 'AGG', 'GAT']
# ['TCC', 'CTT', 'GCT', 'CTG', 'ACG', 'GGG', 'GAG', 'GCT', 'TCC', 'TCA', 'AAC', 'AGG', 'GCC', 'TTT', 'AAG', 'CAG', 'TTT', 'CAC', 'AAC', 'CAG', 'GCT', 'TTC', 'ACC', 'AGT', 'CTG', 'AAA', 'TGT', 'GGT', 'GGG', 'AGG', 'AAG', 'GTA', 'AAC', 'ATT', 'CAG', 'AGA', 'TCG', 'CCG', 'CGA', 'CCA', 'TAC', 'CTG', 'CAT', 'AAA', 'GTA', 'ACA', 'GTC', 'CCA', 'GAC', 'GAC']
# ['TTT', 'GCG', 'ATC', 'AGC', 'GGC', 'CCT', 'GAA', 'AGG', 'CTG', 'TCC', 'GGT', 'TCA', 'GAC', 'AAA', 'GCT', 'TAC', 'TCA', 'CTT', 'TGG', 'AAC', 'AGA', 'CCA', 'GGC', 'ACC', 'TTT', 'ACA', 'GTC', 'AAC', 'AGG', 'TCA', 'CGG', 'TGT', 'AAG', 'AAC', 'AGT', 'AAG', 'CGG', 'TTC', 'TAT', 'ACC', 'AAT', 'GTT', 'TGT', 'AGA', 'CTC', 'GCA', 'CCA', 'GTC', 'TTA', 'GAC']
# ['CGC', 'GTA', 'GGG', 'TCA', 'CTG', 'CAC', 'CCT', 'CAC', 'AAC', 'TTG', 'TCG', 'GAG', 'TGC', 'GGT', 'AAG', 'CGA', 'TTC', 'CTG', 'AGT', 'TGT', 'ATT', 'CCC', 'ACC', 'GTG', 'CTG', 'GGG', 'AGG', 'GCT', 'TCT', 'CGA', 'TGT', 'TGC', 'CTG', 'AAG', 'GTA', 'GCT', 'AGT', 'TCG', 'GGT', 'AAG', 'AAA', 'TTG', 'AGT', 'CGC', 'GAG', 'TTT', 'CCC', 'GCA', 'ACC', 'GAT']
# ['CCA', 'TTA', 'TTT', 'ACT', 'AGG', 'AGG', 'ATT', 'TTA', 'GGT', 'GTT', 'ATT', 'AGT', 'GTG', 'AGC', 'TCG', 'TTA', 'GCG', 'GGT', 'AGT', 'CAG', 'TTA', 'GTC', 'AAC', 'GTA', 'ATC', 'ATT', 'TGG', 'CTG', 'CTA', 'GCT', 'CCT', 'TCT', 'GGC', 'TAT', 'GCT', 'TGT', 'CAT', 'TCT', 'CAA', 'CGC', 'GCC', 'CCC', 'CAC', 'AGA', 'CCA', 'CGG', 'AGT', 'AAT', 'ACG', 'GAC']
# ['AGT', 'AGC', 'GCA', 'CAC', 'ATA', 'TAT', 'AGG', 'AGG', 'CCA', 'ATA', 'ATC', 'AAC', 'GAG', 'CAC', 'TTA', 'CTA', 'ATA', 'ATA', 'AGA', 'GTC', 'CTA', 'ACA', 'CAT', 'GAC', 'GCG', 'CAC', 'CGT', 'TAT', 'TCA', 'AAT', 'CAG', 'TAT', 'AGC', 'ACT', 'ACC', 'GCG', 'CCT', 'TTG', 'TTG', 'CGG', 'ACC', 'GCG', 'GAC', 'CGG', 'CGT', 'GTC', 'ACT', 'GCA', 'ACG', 'GAT']
# ['ATT', 'AGC', 'CGC', 'GGC', 'AGA', 'TTG', 'GTG', 'TCA', 'GAT', 'GAT', 'AAC', 'CTC', 'CCT', 'GCC', 'AAG', 'TTC', 'GTG', 'TGT', 'GTT', 'CTC', 'AGG', 'CGA', 'TCA', 'TGG', 'GGT', 'TTA', 'TCC', 'CTG', 'GGC', 'TTC', 'CCA', 'TTC', 'TCG', 'AAG', 'TTA', 'CCA', 'GTG', 'TAT', 'AGT', 'ATC', 'GAG', 'TAC', 'ACA', 'CGG', 'CAA', 'CAA', 'CTG', 'GCA', 'TAT', 'GAT']
# ['AAT', 'TCT', 'GCA', 'CGG', 'GAA', 'AGC', 'AGG', 'GTA', 'ACT', 'AAA', 'CTT', 'GTA', 'TTT', 'AAA', 'GCC', 'AAG', 'GGG', 'GAG', 'TGG', 'GCG', 'TAT', 'GTG', 'AGC', 'TAT', 'TCG', 'GAT', 'TTT', 'GAG', 'AAC', 'AAT', 'GTA', 'ACT', 'CTC', 'CCC', 'TCA', 'GTG', 'CGA', 'GAT', 'CCC', 'TCG', 'GGG', 'TAT', 'CGC', 'GAA', 'GTG', 'TGG', 'TTT', 'ACC', 'TTG', 'GAT']
# ['ACG', 'GCT', 'TCT', 'CCT', 'CCT', 'ATA', 'CCC', 'TGC', 'CTT', 'CGG', 'AGA', 'CTT', 'CCT', 'AAC', 'GAC', 'CTT', 'CAT', 'GGG', 'CTA', 'CGG', 'ACT', 'CAT', 'TAC', 'AAG', 'CTG', 'ACC', 'GAG', 'TAT', 'TTG', 'TGG', 'GGT', 'GAC', 'ATC', 'TGT', 'TTG', 'CGC', 'CAG', 'AGA', 'CCT', 'AAG', 'GGC', 'CCC', 'GGA', 'ACG', 'GAC', 'GTA', 'TGC', 'GCT', 'TCC', 'GAT']
# ['GGC', 'CGT', 'TTA', 'GGT', 'AGT', 'TGG', 'GGG', 'TTT', 'TCG', 'TCG', 'ATT', 'TCG', 'AGC', 'CGT', 'GTG', 'ACA', 'GAT', 'AGA', 'GGC', 'TTC', 'CGC', 'TCC', 'AGG', 'AGA', 'CAA', 'TCA', 'ACG', 'GGG', 'ATC', 'GAA', 'CTT', 'GCT', 'CAA', 'CGT', 'TCC', 'GAT', 'TCT', 'ATT', 'CTA', 'ATA', 'CTC', 'GCG', 'AGG', 'GTG', 'CGC', 'GAA', 'GCC', 'GTT', 'GAG', 'GAC']
# ['TTA', 'CCA', 'AGC', 'CCA', 'GAG', 'CTA', 'TGG', 'GCT', 'GCG', 'CTT', 'CAG', 'ATC', 'CCC', 'GGC', 'AGA', 'CAT', 'AGT', 'TCC', 'CTT', 'GAA', 'GTG', 'TAT', 'TGG', 'CCC', 'CGA', 'TGG', 'CCG', 'TGT', 'TCT', 'GTC', 'ACC', 'ACT', 'GAG', 'AGC', 'CTC', 'CTA', 'AAC', 'TGT', 'CAT', 'CCA', 'CAT', 'AGC', 'TTC', 'GAC', 'CTA', 'CTG', 'TTC', 'TTA', 'CTG', 'GAC']
# ['TGT', 'TCC', 'TCA', 'CAC', 'GAT', 'CTG', 'CTC', 'TGG', 'CTC', 'GGG', 'CCC', 'GGC', 'CGG', 'TCC', 'GAG', 'GAT', 'ATT', 'CCC', 'CTT', 'AAT', 'GAA', 'GCA', 'TAC', 'GAA', 'GCA', 'GAA', 'CGC', 'GAT', 'AGG', 'GAC', 'AGA', 'TGC', 'TCC', 'CCG', 'TAC', 'GGT', 'CCG', 'GAC', 'TTC', 'TCA', 'GAA', 'TTT', 'GAT', 'TTT', 'CCC', 'ATT', 'AGG', 'AGT', 'GAT', 'GAT']
# ...
# ['CGC', 'CCT', 'AAC', 'CGC', 'ATT', 'CCG', 'GTC', 'GGT', 'CCA', 'AAT', 'CGG', 'AAG', 'GCC', 'ATA', 'GAA', 'TGT', 'CGC', 'ACG', 'ACT', 'TTT', 'AAT', 'CGC', 'TTT', 'GCG', 'CTC', 'AAT', 'AGG', 'TGT', 'TCA', 'ATT', 'CCG', 'CCA', 'GCC', 'GCG', 'AAT', 'TGG', 'GCA', 'AGG', 'CCC', 'CCC', 'CGC', 'GTA', 'GCG', 'CCC', 'ACA', 'GCC', 'TTT', 'CTG', 'TTT', 'TGG']
# ['ATC', 'CTT', 'CGG', 'CTG', 'CGT', 'AGA', 'TTG', 'GAA', 'GAA', 'CGG', 'AAA', 'TCA', 'GTA', 'TTG', 'CAG', 'TCC', 'TTG', 'TAT', 'GCA', 'CTC', 'ACG', 'CTG', 'CGG', 'CAC', 'ACA', 'CCA', 'GGA', 'TCG', 'CTA', 'GCG', 'GAG', 'TGG', 'TCC', 'TCA', 'CAC', 'TTA', 'GAA', 'ACA', 'GAT', 'CGA', 'GTA', 'CCG', 'ATT', 'ATA', 'CGG', 'TTC', 'AAG', 'GTG', 'CTA', 'TGG']
# ['ACT', 'GTA', 'TGG', 'GAG', 'ACC', 'GCG', 'GGT', 'TCT', 'AAA', 'ATA', 'CCT', 'AAG', 'AAC', 'TAT', 'CGG', 'TTA', 'CCT', 'GTC', 'AGT', 'TTT', 'GAA', 'TGC', 'TCA', 'AAG', 'CGT', 'GAC', 'GCG', 'CTA', 'CCA', 'ATT', 'AGG', 'TAT', 'CTT', 'CGG', 'GCA', 'TTC', 'CTC', 'CCG', 'GTT', 'GAG', 'GCC', 'ACG', 'AAT', 'TCA', 'TGG', 'GAG', 'TTT', 'TCT', 'TCC', 'TGG']
# ['TGT', 'AGG', 'GAT', 'ATA', 'AGA', 'CTT', 'CCC', 'AAG', 'TCG', 'AAT', 'TCT', 'CTT', 'TAT', 'CAT', 'CTA', 'TTA', 'GAT', 'CGC', 'ACG', 'TTG', 'CAT', 'GTA', 'GGC', 'AAG', 'GTA', 'TTC', 'TGC', 'AGC', 'CCG', 'GAC', 'GCC', 'CTA', 'GAC', 'GAG', 'CCA', 'ACA', 'CGA', 'ATT', 'CCG', 'GTG', 'TGT', 'AAC', 'ATT', 'GGC', 'TAC', 'GAG', 'GAG', 'TTC', 'CCA', 'TGG']
# ['CTG', 'GCA', 'TAT', 'CAG', 'CGG', 'AAA', 'GGC', 'ATC', 'ACA', 'CTG', 'CAT', 'AAT', 'CTG', 'TGT', 'TTC', 'GTT', 'TCG', 'AAT', 'ATC', 'TAT', 'CAT', 'GAC', 'GAG', 'CTT', 'CGC', 'TTG', 'CGG', 'TCG', 'ATC', 'GGT', 'CCA', 'CCG', 'AAT', 'CTC', 'GAC', 'CAT', 'CGC', 'ACC', 'GGA', 'CTG', 'ACC', 'CTA', 'CAG', 'ACC', 'TCG', 'GTG', 'AGT', 'ACG', 'CGT', 'TGG']
# ['CGG', 'GCG', 'GGT', 'AGG', 'AAC', 'TTT', 'CAC', 'CTA', 'TCC', 'GGA', 'GGT', 'CAC', 'TCC', 'CGT', 'GCC', 'GGT', 'GGA', 'TCT', 'GGC', 'CAC', 'GAT', 'GCC', 'TTG', 'GAC', 'ACA', 'TCA', 'CAA', 'TAT', 'AGT', 'GCT', 'TTT', 'TTG', 'TTA', 'GCC', 'CTA', 'CTT', 'CAC', 'TTG', 'GAA', 'GTG', 'TGT', 'GAT', 'CAT', 'CAC', 'TTA', 'TTC', 'TTC', 'GCT', 'TAC', 'TGG']
# ['GGC', 'CCC', 'GGA', 'AAT', 'ATC', 'TTG', 'ACA', 'ACT', 'TCC', 'TGT', 'TCG', 'CGC', 'CAT', 'CAG', 'ACA', 'CTA', 'GCA', 'CTT', 'GTG', 'ACC', 'AAT', 'CCT', 'GAC', 'GTA', 'GTG', 'GGG', 'GTG', 'GCG', 'GCG', 'TAC', 'AGC', 'CGC', 'GGT', 'CAC', 'AGT', 'CTC', 'GCC', 'ATC', 'CGC', 'TGG', 'CGG', 'CGA', 'CGC', 'GAA', 'GGT', 'TTT', 'CAC', 'GAC', 'GCC', 'TGG']
# ['CCG', 'CAA', 'TCG', 'GGC', 'ATC', 'AAA', 'TAT', 'TGT', 'ATC', 'TGC', 'CAC', 'ACA', 'GCA', 'TTA', 'TAC', 'TGT', 'TAT', 'CTG', 'AAA', 'ATT', 'CGG', 'ACT', 'CGA', 'GAT', 'CCC', 'CCC', 'GCC', 'GAA', 'TTA', 'CTC', 'GAC', 'CAG', 'CAG', 'ACG', 'CGG', 'AGC', 'CCA', 'AGC', 'AGC', 'GCC', 'TGT', 'GCT', 'AAG', 'GCC', 'TTC', 'TCT', 'AGC', 'CAG', 'AGT', 'TGG']
# ['GAG', 'GAT', 'CAA', 'AGA', 'CTA', 'CGA', 'AGG', 'CAC', 'TTC', 'AAT', 'CGC', 'TCC', 'CCG', 'TAC', 'GCG', 'CTA', 'CCA', 'GTC', 'GGG', 'CGC', 'TCT', 'GTA', 'GGG', 'GCA', 'AAT', 'ATT', 'CCG', 'GGC', 'AGC', 'GCA', 'CGC', 'TAT', 'ACT', 'AGA', 'AAT', 'GCG', 'GTT', 'ATT', 'CTC', 'CGG', 'CGG', 'TGC', 'AGG', 'TCC', 'CAC', 'ACT', 'GGG', 'TAC', 'GCG', 'TGG']
# ['GGC', 'CTT', 'CGC', 'GCC', 'CGC', 'CCA', 'GCA', 'GAT', 'CGT', 'CAC', 'GGA', 'CGT', 'GAC', 'AAC', 'AGT', 'CTA', 'TAT', 'GCT', 'TGG', 'GCG', 'ACC', 'GTG', 'CGC', 'CCA', 'ATC', 'AGC', 'CTT', 'TTG', 'TCA', 'CTG', 'CGC', 'GCG', 'GCT', 'ATT', 'AGC', 'GCG', 'TGC', 'TTT', 'GGG', 'TAC', 'TTA', 'CAA', 'AAA', 'CGA', 'CGT', 'CCT', 'GGG', 'TTC', 'GTT', 'TGG']
# ['CCA', 'CAA', 'AGC', 'CAG', 'CAC', 'CAT', 'CGG', 'AAG', 'GAC', 'GCG', 'CGA', 'AGC', 'GTG', 'GCA', 'ACC', 'AGC', 'GTT', 'TGG', 'TTT', 'CTG', 'GGT', 'ATA', 'GTT', 'TTA', 'AAG', 'CAG', 'AAT', 'TGC', 'TTC', 'TCT', 'CTC', 'AGA', 'CTC', 'TCT', 'GCG', 'CTG', 'AGC', 'CTT', 'CTC', 'GCG', 'TAC', 'ATA', 'GCC', 'GTC', 'AGG', 'GGT', 'GAT', 'CCC', 'AAT', 'TGG']
# ['ACT', 'CCG', 'CAC', 'CGG', 'AAA', 'AAA', 'CGC', 'GCG', 'CAA', 'ACC', 'TAT', 'GAA', 'ACT', 'TGG', 'ACC', 'TTA', 'CGC', 'GGC', 'AAG', 'GTC', 'GCT', 'CGA', 'CAT', 'CAA', 'GCT', 'CAG', 'AGG', 'ACC', 'CGT', 'CAT', 'CCC', 'GAT', 'TCG', 'GGT', 'GAC', 'TTC', 'GGT', 'AAA', 'GAT', 'CAT', 'GCG', 'GAG', 'TTG', 'TAT', 'ATT', 'CTC', 'GAT', 'GTG', 'TCA', 'TGG']
# ['CAT', 'TGG', 'GTT', 'GGT', 'CAT', 'CTG', 'AGG', 'TCG', 'ACG', 'GGA', 'AGA', 'CCG', 'CAG', 'CAG', 'CCG', 'ACT', 'TCC', 'TGT', 'GGC', 'AAT', 'GAA', 'CAT', 'TTC', 'AGA', 'CCG', 'TGC', 'TGG', 'CAA', 'GTT', 'ACT', 'ATC', 'CAT', 'CAT', 'CAC', 'ACG', 'AGA', 'TAC', 'TCT', 'AGT', 'ACG', 'GGT', 'TCC', 'AGT', 'CTC', 'CGA', 'CTG', 'AGC', 'TGT', 'TTC', 'TGG']
# ['GGT', 'GAA', 'GTC', 'AAA', 'GAT', 'GAG', 'GAA', 'ATA', 'CTT', 'CTT', 'ACT', 'GCA', 'TTA', 'CGG', 'TTA', 'GCA', 'AGG', 'GTC', 'CAA', 'TAC', 'TCG', 'ATT', 'CCT', 'CTT', 'CCT', 'GGG', 'GCG', 'ATT', 'TTG', 'TAT', 'CAC', 'GAA', 'TCG', 'GTC', 'GTT', 'GGG', 'GCT', 'GAT', 'ATT', 'AGA', 'TTT', 'GAA', 'CTA', 'GGT', 'AAA', 'AGA', 'CCT', 'CTT', 'AAA', 'TGG']
# ['GTA', 'ACT', 'CTG', 'GAA', 'GTC', 'TTA', 'CCG', 'CTA', 'GTG', 'TCA', 'ACG', 'CGC', 'GTA', 'TAC', 'CGC', 'CCC', 'CAT', 'ATC', 'GTG', 'ACT', 'ATC', 'GTT', 'CTA', 'CTT', 'CAA', 'GGA', 'CTT', 'CTA', 'CCT', 'CCA', 'CCA', 'AAA', 'ATT', 'AGC', 'CAA', 'TTC', 'AAA', 'TAT', 'CGT', 'TCC', 'TAC', 'GAC', 'CGT', 'AGC', 'TCA', 'TTA', 'GGT', 'CCA', 'GGG', 'TGG']
# ['TCT', 'TTA', 'TGG', 'GCT', 'TAC', 'GTT', 'AAA', 'TCG', 'GTA', 'GAA', 'ACG', 'AGG', 'CGT', 'GTT', 'TAT', 'TGG', 'GGC', 'TCC', 'GTG', 'CGC', 'TTA', 'AAA', 'AAG', 'TAT', 'AGT', 'AAA', 'AGA', 'TCC', 'CAG', 'GAT', 'ATT', 'CAA', 'GAA', 'GTT', 'CAG', 'GTG', 'TCT', 'AGC', 'TAT', 'CCT', 'GGA', 'TTC', 'GTG', 'GTA', 'GAC', 'CCT', 'TTG', 'GTA', 'ACC', 'TGG']
# ['AAA', 'GCT', 'CGT', 'TAT', 'CCC', 'AAC', 'CGT', 'AAG', 'TGC', 'TGT', 'CCC', 'GTG', 'TTT', 'CTT', 'CCT', 'GCT', 'CGT', 'TAT', 'TTA', 'GGT', 'AAT', 'GAT', 'GAC', 'GAA', 'TAC', 'TCG', 'GTC', 'ATA', 'CGC', 'CTT', 'GTA', 'CAT', 'GTG', 'TCA', 'TGT', 'GAA', 'GTG', 'GGT', 'CTG', 'GCG', 'ACA', 'GAG', 'CGC', 'CCC', 'ATC', 'TCA', 'AGA', 'GAT', 'ACG', 'TGG']
# ['CGT', 'CCG', 'CTA', 'TCA', 'GCG', 'TTG', 'TGC', 'CGC', 'AGG', 'GTG', 'TTC', 'GTC', 'ACT', 'CGC', 'ACT', 'CCT', 'TCT', 'ACG', 'TCA', 'TAT', 'CTA', 'ACC', 'AGT', 'AAC', 'GTA', 'GAG', 'TCA', 'ACC', 'AGT', 'TTG', 'GAA', 'ACT', 'TTC', 'AGA', 'TCA', 'GAA', 'GAG', 'GAG', 'TGC', 'TCA', 'ATT', 'GAG', 'GGG', 'AAG', 'GTC', 'TCA', 'CAT', 'GTA', 'AGT', 'TGG']
# ['GGC', 'CAC', 'CAC', 'TAT', 'CGC', 'TGT', 'CGC', 'GTC', 'GCC', 'CTT', 'CTT', 'ACA', 'TAT', 'GTG', 'TCA', 'GCG', 'CCG', 'TAT', 'GGC', 'GAG', 'AAA', 'GCC', 'ATA', 'CTA', 'CGA', 'AAG', 'TGC', 'TAC', 'CGC', 'GAA', 'ATT', 'CTT', 'GAC', 'CAG', 'CAC', 'TAT', 'CGT', 'CTA', 'TCT', 'AAA', 'CAG', 'CCA', 'ACC', 'ATT', 'GCT', 'AAC', 'CAA', 'GGT', 'ATT', 'TGG']
# ['CTG', 'GGA', 'CAC', 'GTC', 'CCG', 'AGC', 'GAT', 'AAA', 'ACG', 'GTT', 'TCC', 'GCG', 'TAT', 'GGG', 'CTC', 'CTC', 'CCG', 'CTC', 'GAC', 'GAA', 'AGA', 'GCT', 'GAT', 'CGC', 'TTA', 'GCA', 'CGC', 'CCG', 'CCA', 'TCT', 'AGC', 'GTG', 'GTT', 'GTG', 'ATA', 'GAC', 'AAC', 'GCA', 'CAA', 'GAT', 'ATT', 'GTA', 'AGT', 'TCC', 'GGG', 'GTC', 'TCG', 'AGT', 'GAA', 'TGG']
# ['AAT', 'GGT', 'GAG', 'CGT', 'ATA', 'GAG', 'ACT', 'ACT', 'TTA', 'GCG', 'TTC', 'GCT', 'CGT', 'CCG', 'TTT', 'CCT', 'TCC', 'TTT', 'CCT', 'CAC', 'GGG', 'TAC', 'GAT', 'CCG', 'TTA', 'CCC', 'TCG', 'GTG', 'CTA', 'TAC', 'TCA', 'CGT', 'CAC', 'GTT', 'CCC', 'GTA', 'GTG', 'GCG', 'TAT', 'GAG', 'CGT', 'TCA', 'CCA', 'GCC', 'AGG', 'CCC', 'TTC', 'AGA', 'ATT', 'TGG']
# ['CGG', 'CTT', 'CCG', 'GGA', 'AGC', 'TTG', 'ATA', 'AAG', 'TTT', 'AGT', 'AAA', 'TGT', 'CGC', 'CAT', 'CGA', 'TAC', 'CAT', 'ACA', 'GCT', 'AGG', 'TTC', 'GTA', 'GCC', 'TTA', 'GTA', 'GTG', 'GGA', 'TAC', 'AAT', 'ACC', 'GAC', 'GAC', 'TCT', 'TGG', 'CGG', 'ATT', 'AGT', 'GCA', 'ATC', 'ATT', 'AAT', 'ATT', 'CTA', 'AGC', 'AAG', 'GTC', 'AAA', 'GCG', 'TCA', 'TGG']
# ['AGA', 'CGA', 'TAT', 'AGA', 'CGG', 'CCT', 'GTC', 'TCC', 'CGT', 'CAC', 'GTC', 'GCG', 'TAT', 'ACG', 'TGC', 'AAT', 'GCC', 'AGC', 'CAA', 'GGC', 'AAA', 'CTC', 'ATA', 'CAA', 'TGG', 'GGG', 'AGC', 'GTG', 'CCT', 'TCT', 'TCC', 'GAG', 'GCC', 'ATC', 'AAG', 'CCA', 'AAT', 'TCT', 'TCC', 'GTG', 'AAT', 'ATT', 'CTT', 'AAG', 'TGT', 'GCA', 'ATT', 'ACT', 'AAC', 'TGG']
# ['TGG', 'GAG', 'CGC', 'CTT', 'AGA', 'TTA', 'TTA', 'TAC', 'GTT', 'CAC', 'AGT', 'TAC', 'CGA', 'TAT', 'GAA', 'CGT', 'GAT', 'GCA', 'TTA', 'CTT', 'CCC', 'TTC', 'AAA', 'TCT', 'CTC', 'AGC', 'CGC', 'CGG', 'GAG', 'TGC', 'AGT', 'CTT', 'ACT', 'GGA', 'TTA', 'AAT', 'CGT', 'GCC', 'TTG', 'GGG', 'CGA', 'GCA', 'ATA', 'GGC', 'AAA', 'ACG', 'CGA', 'ACA', 'CTT', 'TGG']
# ['TTT', 'ACA', 'GTA', 'AAT', 'AGC', 'TTT', 'CCC', 'TGG', 'GAG', 'AAA', 'GTA', 'GGC', 'TAT', 'TGT', 'CAT', 'CGT', 'CGC', 'CTA', 'AGT', 'CAT', 'CCA', 'ACG', 'GGC', 'CGA', 'GTA', 'CTC', 'ACA', 'TCC', 'AAC', 'GGG', 'ACT', 'CAT', 'GGC', 'GGA', 'CTG', 'TCG', 'GAC', 'GTA', 'TTT', 'CCG', 'GTT', 'ATT', 'GCC', 'CGG', 'TAT', 'CGA', 'ATA', 'GAG', 'CCC', 'TGG']
# ['TTT', 'ACC', 'GTA', 'GGT', 'TTA', 'GGT', 'AAG', 'ACT', 'TGG', 'ACT', 'CGT', 'ATT', 'CAC', 'CGA', 'CCG', 'AAG', 'ATA', 'TGT', 'AAG', 'GAT', 'CAA', 'TGG', 'AAG', 'GGT', 'TGG', 'CTG', 'AGC', 'GGG', 'AAC', 'CCA', 'CAG', 'GTT', 'AAT', 'GCT', 'GGA', 'TGG', 'GGG', 'GTA', 'AGT', 'CGA', 'GCC', 'GCG', 'CGC', 'TGT', 'CTT', 'TTA', 'GTA', 'CTG', 'TCC', 'TGG']
# ['GCA', 'GGA', 'AAC', 'AGG', 'GAC', 'CCA', 'TCA', 'TAC', 'AGA', 'ATA', 'TCG', 'CTC', 'CCC', 'ACC', 'AAC', 'ACT', 'AAC', 'GCG', 'AAG', 'GGC', 'AGG', 'TTT', 'TGC', 'CCC', 'CTA', 'GTA', 'CGC', 'CTT', 'CGC', 'GAG', 'GCT', 'TCA', 'AGA', 'AGG', 'CTG', 'TTA', 'AAG', 'TCT', 'CGT', 'CAG', 'GGA', 'ATC', 'GGC', 'GCC', 'TAC', 'AGC', 'GCA', 'AGC', 'AGT', 'TGG']
# ['CAC', 'AAT', 'TTC', 'TCA', 'TTG', 'GTT', 'GCA', 'GCA', 'ACG', 'TCA', 'CGG', 'CCG', 'CAG', 'ACC', 'GCT', 'TTA', 'ACT', 'TCG', 'GAT', 'TCA', 'CAC', 'TTC', 'GTC', 'GAA', 'GTT', 'GCT', 'TCA', 'GTT', 'GGT', 'CTA', 'GAT', 'TCA', 'TCA', 'GTG', 'GTA', 'CCT', 'GGA', 'TCA', 'TGG', 'GGA', 'GAT', 'GGA', 'CAG', 'CAG', 'GGC', 'GCA', 'TAC', 'ATA', 'ATT', 'TGG']
# ['GGA', 'TTT', 'CGC', 'GAG', 'ATC', 'TGC', 'TGG', 'GTG', 'CTT', 'GAC', 'GAT', 'TCG', 'AGA', 'TAC', 'TTG', 'ATT', 'GCA', 'ATA', 'CGC', 'ACT', 'CGT', 'GCG', 'ACT', 'CGT', 'GCG', 'TGT', 'TGG', 'AAC', 'GAA', 'TGC', 'TGC', 'GGT', 'AGT', 'ATA', 'GCA', 'TTA', 'AAC', 'AGA', 'ATA', 'ACG', 'TAT', 'AAA', 'TTG', 'TGC', 'CTT', 'TAC', 'AAC', 'GGG', 'GAA', 'TGG']
# ['GTC', 'ATC', 'ACC', 'CTA', 'AAC', 'CTC', 'AAT', 'AAG', 'AGA', 'CTC', 'CCC', 'CCC', 'TGC', 'GTT', 'ACC', 'CTC', 'CAG', 'CTC', 'AAG', 'GGT', 'CGA', 'ACT', 'AAC', 'TCC', 'GAA', 'TCA', 'AAG', 'CCC', 'TCA', 'TGG', 'GGA', 'AAT', 'CGT', 'CAA', 'GAA', 'GCA', 'AGA', 'ACT', 'CCC', 'GTT', 'GAC', 'CTG', 'AAT', 'AGT', 'CTA', 'GGG', 'TCC', 'TGG', 'AAC', 'TGG']
# ['GAC', 'ACC', 'GTA', 'ACG', 'TGC', 'TTA', 'GCC', 'ACC', 'ACT', 'GTT', 'CCT', 'AAC', 'ATT', 'GAG', 'GCT', 'AGC', 'ATA', 'GGT', 'GGT', 'TGC', 'ATT', 'CTC', 'CCA', 'GGC', 'TGG', 'TCT', 'CAC', 'AAC', 'TGT', 'GCG', 'GTG', 'AGT', 'CGC', 'TAC', 'CTT', 'AAG', 'GAG', 'TAC', 'AAC', 'GGG', 'CTT', 'CCT', 'ACA', 'GAA', 'TTA', 'CAA', 'ATC', 'CAG', 'GAC', 'TGG']
# ['GTT', 'TGG', 'GAG', 'TGG', 'CTT', 'TGG', 'CAT', 'GCA', 'TTC', 'GAG', 'AGG', 'AAC', 'TGT', 'GCC', 'AAA', 'CTT', 'GTA', 'CCA', 'GAC', 'AGA', 'TCT', 'ACC', 'GCA', 'TGC', 'CCG', 'TTT', 'CCT', 'CCA', 'GCA', 'AGT', 'GTA', 'TCA', 'TGT', 'CAT', 'TCC', 'GGC', 'CGT', 'CAG', 'ATA', 'TCC', 'AAG', 'TGC', 'ACT', 'TCA', 'CGC', 'GTG', 'TTG', 'CCC', 'ATC', 'TGG']
# ['TAT', 'ATT', 'CAC', 'GCA', 'AGT', 'CCC', 'TGT', 'GTA', 'CCT', 'GAT', 'CTC', 'CTG', 'GCT', 'AAC', 'CCA', 'ACC', 'AGT', 'CAG', 'CGG', 'AAC', 'TAC', 'CAA', 'AGG', 'TTG', 'ACG', 'GCC', 'CCG', 'ATA', 'TCG', 'AGA', 'GAG', 'AAT', 'AGC', 'TAC', 'GGA', 'TTC', 'GTT', 'CTC', 'ATA', 'ATT', 'GGG', 'ATC', 'CAG', 'GGA', 'GCA', 'TCG', 'CGG', 'TGT', 'AAC', 'TGG']
# ['TCG', 'AAC', 'CGT', 'CCT', 'AGG', 'GTA', 'CTG', 'AAA', 'TCC', 'ATA', 'TAC', 'GAA', 'CGC', 'GCT', 'CGT', 'CCC', 'TCA', 'CCC', 'TCA', 'AGA', 'CCC', 'CGA', 'CTC', 'AGC', 'TCT', 'GCT', 'GCG', 'ACC', 'CAG', 'GAC', 'AAA', 'GTT', 'CAG', 'TGC', 'GTA', 'CTT', 'CTG', 'TTG', 'AAG', 'GAG', 'ATC', 'GCG', 'CAT', 'TAC', 'GGT', 'GAC', 'GAC', 'CCT', 'TTG', 'TGG']
# ['TAT', 'GAT', 'TCG', 'ATC', 'CCT', 'GCA', 'AAC', 'CCG', 'GTG', 'TTT', 'GGC', 'ATC', 'TAT', 'TGC', 'CGT', 'AAA', 'GCC', 'CAA', 'AGT', 'CGT', 'CAA', 'CCT', 'GAA', 'GAT', 'ATC', 'ATC', 'CCT', 'CGG', 'TAT', 'CAC', 'CTG', 'CCC', 'TTC', 'TTC', 'ATC', 'CTT', 'CAT', 'TTA', 'GGG', 'ACG', 'TGT', 'AGT', 'CCC', 'CTG', 'CTG', 'GTA', 'TCA', 'CTT', 'ATC', 'TGG']
# ['CAC', 'TCT', 'CCC', 'GGC', 'TCA', 'ACC', 'AGT', 'TTC', 'TGG', 'ACG', 'ATC', 'CCG', 'ATC', 'GTT', 'GAG', 'CAT', 'CCA', 'GGA', 'GAA', 'TGC', 'CGT', 'AGT', 'TTG', 'GTT', 'CCT', 'CGG', 'GCA', 'GCC', 'GCT', 'TAT', 'TTA', 'TCT', 'GTT', 'CTC', 'GCC', 'GCA', 'ATT', 'CTA', 'CAT', 'CAA', 'ATC', 'ACC', 'GAT', 'TCA', 'AGG', 'CAC', 'CCG', 'CCA', 'CTA', 'TGG']
# ['ATA', 'CGG', 'AGT', 'TTG', 'CAA', 'AAA', 'TTT', 'TCG', 'CCG', 'TCG', 'CTA', 'CCG', 'ACG', 'CGA', 'AGA', 'CAT', 'ACA', 'TAC', 'AGC', 'AAC', 'CTA', 'CAC', 'CTG', 'CGA', 'TCA', 'AAT', 'TGC', 'GGC', 'TTA', 'CGC', 'CGG', 'GAC', 'CCT', 'GTA', 'TCA', 'GAC', 'CCC', 'ACT', 'GAT', 'TCA', 'ATC', 'ACA', 'GCT', 'TCG', 'CTT', 'TGC', 'CCC', 'GTC', 'TGG', 'TGG']
# ['CAA', 'GTT', 'CCA', 'GAA', 'CCT', 'GCT', 'GTT', 'GAT', 'TCC', 'GTT', 'GTA', 'GAC', 'TAC', 'TCA', 'GAT', 'CTT', 'TTC', 'ATA', 'AGA', 'GGG', 'AAA', 'ATC', 'ACA', 'TTG', 'ATC', 'TAT', 'ACC', 'GAC', 'GTC', 'CCA', 'ACG', 'ACA', 'GAG', 'ATC', 'GAT', 'CCA', 'TCC', 'GTA', 'ACA', 'GGT', 'CAC', 'CAA', 'GAT', 'GAA', 'GTA', 'AGA', 'TGC', 'CAC', 'GCA', 'TGG']
# ['TAT', 'CCA', 'TGG', 'CCT', 'TTC', 'GCA', 'ACC', 'CAC', 'AGC', 'AGC', 'GCT', 'TCG', 'GTT', 'GGA', 'ACG', 'CGC', 'GCT', 'TCA', 'GGG', 'GGG', 'TCA', 'TTT', 'TCA', 'TAT', 'CAG', 'TAT', 'GGC', 'GAT', 'ACA', 'TTG', 'AGG', 'AGC', 'CTA', 'GGC', 'TCC', 'GGT', 'TTA', 'GCC', 'ACG', 'CTA', 'AAG', 'ACA', 'AAG', 'CTC', 'CCC', 'TCA', 'CAG', 'CTC', 'CGT', 'TGG']
# ['CGA', 'CAA', 'AGA', 'CAT', 'ATA', 'AAC', 'CGT', 'GTA', 'ACA', 'CGA', 'TAT', 'CAC', 'CCG', 'GTG', 'GTA', 'AAG', 'ACA', 'CTA', 'AAA', 'GTC', 'CTA', 'TTC', 'ACC', 'TTA', 'GTA', 'CGA', 'ATA', 'CTG', 'ATT', 'GTA', 'GAT', 'AAG', 'CCT', 'TAT', 'GTC', 'AAC', 'AGT', 'TTC', 'CGT', 'TCG', 'CCT', 'CCG', 'TTT', 'ACC', 'GAG', 'TGC', 'CGT', 'AGA', 'TGC', 'TGG']
# ['GCG', 'CAA', 'GTA', 'GTC', 'GAT', 'CTA', 'AGA', 'TGT', 'CCC', 'GGG', 'CTG', 'ACC', 'CTT', 'ACT', 'GAG', 'TTG', 'CCC', 'AAG', 'GCA', 'GTG', 'CCG', 'CGT', 'CGG', 'CAT', 'AAG', 'CAC', 'ACC', 'TGC', 'GGG', 'GCG', 'TCC', 'AGG', 'TTT', 'GTC', 'ACT', 'CAT', 'CAA', 'CCA', 'GCA', 'TCT', 'CCC', 'GCG', 'ACA', 'AGT', 'CGT', 'AGA', 'ACG', 'CTT', 'CCG', 'TGG']
# ['ATA', 'GTT', 'TGT', 'AGC', 'TTA', 'CGT', 'CGT', 'GGT', 'TTT', 'GAT', 'GGG', 'ATA', 'TCG', 'CTC', 'AAT', 'CAT', 'TAC', 'AGT', 'GGA', 'CAC', 'ATT', 'CGC', 'CCA', 'CGC', 'CCT', 'GTA', 'TGG', 'AAC', 'ATA', 'AAA', 'GGT', 'ATA', 'CTT', 'CCT', 'TAC', 'GTG', 'GGA', 'GAT', 'AAT', 'CGT', 'TCC', 'ATT', 'CTG', 'GAT', 'GGA', 'CAC', 'CAC', 'TCA', 'TAC', 'TGG']
# ['CTT', 'GAA', 'AGC', 'TTA', 'GAT', 'AGG', 'GTC', 'GAG', 'CGG', 'ACT', 'CCG', 'AGA', 'TGT', 'GTG', 'CCG', 'CTG', 'TTG', 'ACA', 'TGT', 'CCC', 'ATT', 'TCA', 'GAG', 'AGC', 'TGC', 'CGA', 'CGG', 'AAA', 'GAG', 'CTA', 'CCA', 'AAA', 'TGG', 'CCC', 'GAC', 'CTG', 'TTA', 'AAG', 'CAA', 'GAT', 'TGT', 'CGC', 'GTC', 'GAG', 'TGT', 'ATC', 'TCG', 'TTG', 'CTG', 'TGG']
# Finished class:  16
# protein  ['GAG', 'TTC', 'CCC', 'GTA', 'GCA', 'TCA', 'TTC', 'AGG', 'CCG', 'ATT', 'GAC', 'CAA', 'GGC', 'GAA', 'GAA', 'CAA', 'CTC', 'AAG', 'AGC', 'AAC', 'TCG', 'CAC', 'AAT', 'ATC', 'TCA', 'GAC', 'TAC', 'AGG', 'ACA', 'GTC', 'CAT', 'TTG', 'TAC', 'AAA', 'CAA', 'TCA', 'AAG', 'GAG', 'CCG', 'ACG', 'CTC', 'CCC', 'GAC', 'AAT', 'GTA', 'TGG', 'GAA', 'ACA', 'TTT', 'TTC']
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
