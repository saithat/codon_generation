# %%
from random import *
import csv

# %%
DNA_codon_table = [
        ("ATG","M/Start"), ("ATA","I"), ("ATC","I"), ("ATT","I"), ("ACG","T"), ("ACA","T"),
        ("ACC","T"), ("ACT", "T"), ("AAG","K"), ("AAA","K"), ("AAC","N"), ("AAT","N"),
        ("AGG","R"), ("AGA","R"), ("AGC","S"), ("AGT","S"), 
        ("GTG","V"), ("GTA","V"), ("GTC","V"), ("GTT","V"), ("GCG","A"), ("GCA","A"), ("GCC","A"), ("GCT","A"), 
        ("GAG","E"), ("GAA","E"), ("GAC","D"), ("GAT","D"), ("GGG","G"), ("GGA","G"), ("GGC","G"), ("GGT","G"), 
        ("CTG","L"), ("CTA","L"), ("CTC","L"), ("CTT","L"), ("CCG","P"), ("CCA","P"), ("CCC","P"), ("CCT","P"),
        ("CAG","Q"), ("CAA","Q"), ("CAC","H"), ("CAT","H"), ("CGG","R"), ("CGA","R"), ("CGC","R"), ("CGT","R"),
        ("TTG","L"), ("TTA","L"), ("TTC","F"), ("TTT","F"), ("TCG","S"), ("TCA","S"), ("TCC","S"), ("TCT","S"),
        ("TAC","Y"), ("TAT","Y"), ("TGG","W"), ("TGC","C"), ("TGT","C"), ("TAG","Amber/Stop"),
        ("TAA","Ochre/Stop"),("TGA","Opal/Stop")
]

Nucl = ["A", "T", "G", "C"]

stop = ["TAG", "TAA", "TGA"]

# %%
#rules:
# -1 = default
# 0 - 4 = exclude Nucleotide
def create_protein(seq_length, rule=-1, rand_pos_pick=-1, AminExcl=0): #AminExcl -# amino acids to exclude
    protein = []
    tmp = []
    Excl = [] # " "
    #if AminExcl == 1:
    #    Excl = DNA_codon_table[randint(1, 61)][1]
    tmp_table = DNA_codon_table[1:61]
    #print(tmp_table)

    if AminExcl > 0: # > 1
        #Excl = []
        for i in range(AminExcl):
            #print(len(tmp_table))
            tmp = tmp_table[randint(0, len(tmp_table)-1)]
            #while(tmp[1] in Excl):
                #print(tmp)
                #tmp_table.remove(tmp)
                #tmp = tmp_table[randint(0, len(tmp_table)-1)]
            Excl.append(tmp[1])
            tmp_table.remove(tmp)
            
    #print("Amino Acid exclusion: ", Excl)
    triplet = DNA_codon_table[randint(1, 60)]
    for j in range(0, seq_length):  #generating one specific protein sequence
        if(rule == -1):
            #protein.append(aminos[randint(0, len(aminos)-1)])  #DNA sequences
            if(rand_pos_pick > -1):
                if(rand_pos_pick == j):
                    tmp = DNA_codon_table[randint(1, 60)]
                    while(tmp[1] == triplet[1]):
                        tmp = DNA_codon_table[randint(1, 60)]
                    protein.append(tmp[0])
                else:          
                    protein.append(triplet[0])
            else:
                protein.append(triplet[0])
            
        else:
            tmp = DNA_codon_table[randint(1, 60)][0]
            #aminos[randint(0, len(aminos)-1)]
            while(Nucl[rule % 4] in tmp):
                tmp = DNA_codon_table[randint(1, 60)][0]
                #aminos[randint(0, len(aminos)-1)]
            protein.append(tmp)
    return protein, Excl

# %%
def num_comb(val, codon_dict):
    pos_comb = 0
    for key, value in codon_dict.items():
        if value == val:
            pos_comb += 1
    return pos_comb

# %%
def find_comb(val, codon_dict, rule=-1):
    combs = []
    for key, value in codon_dict.items():
        if value == val:
            if(rule != -1):
                if(not Nucl[rule % 4] in key):
                    combs.append(key)
            else:
                combs.append(key)
    return combs

# %%
def create_sequences(protein, num_seq, rule=-1, rand_change=0):
    '''
        1. Protein sequence
        2. used_key lists for each amino acid
                           -OR-
           lists of possible key values for each key
    '''
    sequence = []
    tmp = []
    amino_list = []
    protein_len = len(protein)
    for i in range(0, protein_len):
        amino_list.append(False)
    amino_list[0] = True
    codon_dict = dict(DNA_codon_table)
    #print(codon_dict)
    seq_count = 0
    comb_dict = {}
    #comb_list = []
    for i in range(0, len(protein)):
        #print(codon_dict[protein[i]])
        combs = find_comb(codon_dict[protein[i]], codon_dict, rule)
        #print(type(comb_dict))
        comb_dict[i] = combs
        #comb_list.append(combs)
    #print(comb_dict)
    index = 0
    comb_tracker = [0 for i in range(0,len(protein))]
    #print(comb_tracker)

    while seq_count < num_seq:
        for i in range(0, protein_len):
            tmp.append(choice(comb_dict[i]))
        sequence.append(list(tmp))
        tmp = []
        seq_count += 1
        
    #print(sequence)
    #print("amount of sequences: ", len(sequence))
        
    if rand_change > 0:
        rand_samples = randint(1, num_seq-1)  #alter rand_samples amount of sequences in protein class
        #print("rand_samples: ", rand_samples)
        for i in range(rand_samples):
            which_samp = randint(0, num_seq-1) #which seq to modify
            #print("Which samp: ", which_samp)
            for j in range(rand_change):   #which amino acids to modify
                loc = randint(0, protein_len-1)
                #print("location: ", loc)
                sequence[which_samp][loc] = DNA_codon_table[randint(1, 60)][0]
            
            
    return sequence

# %%
def create_set(num_aminos, seq_length, num_classes, seq_per_class):
    s = ""
    if num_aminos < 3:
        print("Need more aminos")
        return
    rand_aminos = []
    classes = []
    seq = []
    Excl = []
    #for i in range(1, num_aminos-3): # -2 because of start and stop codons
    #    rand_aminos.append(DNA_codon_table[randint(1, 62)][0])  #looking at DNA

    for i in range(0, num_classes):  #generating diffferent proteins
        protein, tmp = create_protein(seq_length, -1, rand_pos_pick=(seq_length-1))
        Excl.append(tmp)
        print("protein ", protein)
        seq_list = create_sequences(protein, seq_per_class)
        #for j in seq_list:
        #    j.insert(0, "ATG")
        #    j.append(choice(stop))
        #    seq.append(''.join(j))
        #    classes.append(i)
            #print(j)
        #print(type(seq_new))
        print("Finished class: ", i+1)
    #print(seq)
    return classes, seq, Excl

# %%
num_aminos = 64
seq_length = 50#250
num_classes = 25#100
seq_per_class = 200#20000
keys, val, Excl = create_set(num_aminos, seq_length, num_classes, seq_per_class)
print(len(keys))
#print(len(val))
#list of tuples (x,y) where x is a string and y is index
fout = str(num_aminos) + '_' + str(seq_length) + '_' + str(num_classes) + '_' + str(seq_per_class) + 'same_last'
print(fout)
for i in range(len(Excl)):
    #print("Amino Acid exclusion ", i+1, ": ", Excl[i])
with open('../data/data%s.csv' % fout, 'w') as f:
#with open('data/64_30_30_10.csv', 'w') as f:
    writer = csv.writer(f)
    writer.writerow(['class', 'sequence'])
    for i in range(0, len(keys)):
        writer.writerow([keys[i], val[i]])
# Out:
# protein  ['CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'GCC']
# Finished class:  1
# protein  ['TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'TTA', 'GGG']
# Finished class:  2
# protein  ['ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'ACG', 'GTC']
# Finished class:  3
# protein  ['GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'GTG', 'CCA']
# Finished class:  4
# protein  ['TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'TCA', 'GGC']
# Finished class:  5
# protein  ['CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CCG', 'CAG']
# Finished class:  6
# protein  ['GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'GCG', 'ACT']
# Finished class:  7
# protein  ['GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'GAC', 'AGC']
# Finished class:  8
# protein  ['TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'TAC', 'AGG']
# Finished class:  9
# protein  ['GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GGA', 'GCT']
# Finished class:  10
# protein  ['CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'CCA', 'AAC']
# Finished class:  11
# protein  ['AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'AGC', 'GGC']
# Finished class:  12
# protein  ['CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CAT', 'CTA']
# Finished class:  13
# protein  ['GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'GTC', 'TCT']
# Finished class:  14
# protein  ['CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CGT']
# Finished class:  15
# protein  ['CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'CGG', 'AAC']
# Finished class:  16
# protein  ['CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'CGA', 'AAA']
# Finished class:  17
# protein  ['TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'TGT', 'GCG']
# Finished class:  18
# protein  ['CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'TGG']
# Finished class:  19
# protein  ['TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'AGG']
# Finished class:  20
# protein  ['CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'CCC', 'GTC']
# Finished class:  21
# protein  ['CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'CAA', 'TAT']
# Finished class:  22
# protein  ['GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'GTT', 'AAA']
# Finished class:  23
# protein  ['TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'GAC']
# Finished class:  24
# protein  ['TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'TGC', 'CTC']
# Finished class:  25
# 0
# 64_50_25_200same_last
# Amino Acid exclusion  1 :  []
# Amino Acid exclusion  2 :  []
# Amino Acid exclusion  3 :  []
# Amino Acid exclusion  4 :  []
# Amino Acid exclusion  5 :  []
# Amino Acid exclusion  6 :  []
# Amino Acid exclusion  7 :  []
# Amino Acid exclusion  8 :  []
# Amino Acid exclusion  9 :  []
# Amino Acid exclusion  10 :  []
# Amino Acid exclusion  11 :  []
# Amino Acid exclusion  12 :  []
# Amino Acid exclusion  13 :  []
# Amino Acid exclusion  14 :  []
# Amino Acid exclusion  15 :  []
# Amino Acid exclusion  16 :  []
# Amino Acid exclusion  17 :  []
# Amino Acid exclusion  18 :  []
# Amino Acid exclusion  19 :  []
# Amino Acid exclusion  20 :  []
# Amino Acid exclusion  21 :  []
# Amino Acid exclusion  22 :  []
# Amino Acid exclusion  23 :  []
# Amino Acid exclusion  24 :  []
# Amino Acid exclusion  25 :  []
